# %%
##pip install requests-html

# %%
import time
import re
import requests
#from resquests_html import HTMLSession
import pandas as pd
from bs4 import BeautifulSoup
import numpy as np
import pycountry

# %%
headers= {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/101.0.4951.54 Safari/537.36' 
}

# %%
countrylinks=['ad','ae','al','am','az','ba','be','bg','bh','ca','ch','cn','co','cr','cy','cz','de','dk','do','dz','ee','eg','es','fi','fr','ge','gr','gt','hk','hn','hr','hu','id','ie','il','in','is','it','jo','jp','kr','kw','kz','lb','lt','lu','lv','ma','mc','me','mk','mo','mt','mx','my','nl','no','om','pa','ph','pl','pt','qa','ro','rs','ru','sa','se','sg','si','sk','sv','th','tn','tr','tw','ua','uk','us']

# %%
def build_url(country):
    return 'https://www.zara.com/'+country+'/en/linen-blend-print-dress-p03274740.html?v1=171726299'

# %%
country_urls = [build_url(country) for country in countrylinks]
print(country_urls)
# Out:
# ['https://www.zara.com/ad/en/linen-blend-print-dress-p03274740.html?v1=171726299', 'https://www.zara.com/ae/en/linen-blend-print-dress-p03274740.html?v1=171726299', 'https://www.zara.com/al/en/linen-blend-print-dress-p03274740.html?v1=171726299', 'https://www.zara.com/am/en/linen-blend-print-dress-p03274740.html?v1=171726299', 'https://www.zara.com/az/en/linen-blend-print-dress-p03274740.html?v1=171726299', 'https://www.zara.com/ba/en/linen-blend-print-dress-p03274740.html?v1=171726299', 'https://www.zara.com/be/en/linen-blend-print-dress-p03274740.html?v1=171726299', 'https://www.zara.com/bg/en/linen-blend-print-dress-p03274740.html?v1=171726299', 'https://www.zara.com/bh/en/linen-blend-print-dress-p03274740.html?v1=171726299', 'https://www.zara.com/ca/en/linen-blend-print-dress-p03274740.html?v1=171726299', 'https://www.zara.com/ch/en/linen-blend-print-dress-p03274740.html?v1=171726299', 'https://www.zara.com/cn/en/linen-blend-print-dress-p03274740.html?v1=171726299', 'https://www.zara.com/co/en/linen-blend-print-dress-p03274740.html?v1=171726299', 'https://www.zara.com/cr/en/linen-blend-print-dress-p03274740.html?v1=171726299', 'https://www.zara.com/cy/en/linen-blend-print-dress-p03274740.html?v1=171726299', 'https://www.zara.com/cz/en/linen-blend-print-dress-p03274740.html?v1=171726299', 'https://www.zara.com/de/en/linen-blend-print-dress-p03274740.html?v1=171726299', 'https://www.zara.com/dk/en/linen-blend-print-dress-p03274740.html?v1=171726299', 'https://www.zara.com/do/en/linen-blend-print-dress-p03274740.html?v1=171726299', 'https://www.zara.com/dz/en/linen-blend-print-dress-p03274740.html?v1=171726299', 'https://www.zara.com/ee/en/linen-blend-print-dress-p03274740.html?v1=171726299', 'https://www.zara.com/eg/en/linen-blend-print-dress-p03274740.html?v1=171726299', 'https://www.zara.com/es/en/linen-blend-print-dress-p03274740.html?v1=171726299', 'https://www.zara.com/fi/en/linen-blend-print-dress-p03274740.html?v1=171726299', 'https://www.zara.com/fr/en/linen-blend-print-dress-p03274740.html?v1=171726299', 'https://www.zara.com/ge/en/linen-blend-print-dress-p03274740.html?v1=171726299', 'https://www.zara.com/gr/en/linen-blend-print-dress-p03274740.html?v1=171726299', 'https://www.zara.com/gt/en/linen-blend-print-dress-p03274740.html?v1=171726299', 'https://www.zara.com/hk/en/linen-blend-print-dress-p03274740.html?v1=171726299', 'https://www.zara.com/hn/en/linen-blend-print-dress-p03274740.html?v1=171726299', 'https://www.zara.com/hr/en/linen-blend-print-dress-p03274740.html?v1=171726299', 'https://www.zara.com/hu/en/linen-blend-print-dress-p03274740.html?v1=171726299', 'https://www.zara.com/id/en/linen-blend-print-dress-p03274740.html?v1=171726299', 'https://www.zara.com/ie/en/linen-blend-print-dress-p03274740.html?v1=171726299', 'https://www.zara.com/il/en/linen-blend-print-dress-p03274740.html?v1=171726299', 'https://www.zara.com/in/en/linen-blend-print-dress-p03274740.html?v1=171726299', 'https://www.zara.com/is/en/linen-blend-print-dress-p03274740.html?v1=171726299', 'https://www.zara.com/it/en/linen-blend-print-dress-p03274740.html?v1=171726299', 'https://www.zara.com/jo/en/linen-blend-print-dress-p03274740.html?v1=171726299', 'https://www.zara.com/jp/en/linen-blend-print-dress-p03274740.html?v1=171726299', 'https://www.zara.com/kr/en/linen-blend-print-dress-p03274740.html?v1=171726299', 'https://www.zara.com/kw/en/linen-blend-print-dress-p03274740.html?v1=171726299', 'https://www.zara.com/kz/en/linen-blend-print-dress-p03274740.html?v1=171726299', 'https://www.zara.com/lb/en/linen-blend-print-dress-p03274740.html?v1=171726299', 'https://www.zara.com/lt/en/linen-blend-print-dress-p03274740.html?v1=171726299', 'https://www.zara.com/lu/en/linen-blend-print-dress-p03274740.html?v1=171726299', 'https://www.zara.com/lv/en/linen-blend-print-dress-p03274740.html?v1=171726299', 'https://www.zara.com/ma/en/linen-blend-print-dress-p03274740.html?v1=171726299', 'https://www.zara.com/mc/en/linen-blend-print-dress-p03274740.h ...

# %%
dresslist=[]
for url in country_urls:
    r=requests.get(url,headers=headers)
    soup=BeautifulSoup(r.content,'lxml')
    name=soup.find('h1',class_='product-detail-info__header-name').text.strip()
    price=soup.find('span',class_='price-current__amount').text.strip()
    dress={
    'name': name,
    'price':price
    }
    dresslist.append(dress)
    print('Saving:',dress['name'])
# Out:
# Saving: PRINTED LINEN BLEND DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: LINEN BLEND PRINT DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: LINEN BLEND PRINT DRESS
# Saving: LINEN BLEND PRINT DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: LINEN BLEND PRINT DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: LINEN BLEND PRINT DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: LINEN BLEND PRINT DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: LINEN BLEND PRINT DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: LINEN BLEND PRINT DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: LINEN BLEND PRINT DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: PRINTED LINEN BLEND DRESS
# Saving: LINEN BLEND PRINT DRESS

# %%
print(dresslist)
# Out:
# [{'name': 'PRINTED LINEN BLEND DRESS', 'price': '35.00 EUR'}, {'name': 'PRINTED LINEN BLEND DRESS', 'price': '299.00 AED'}, {'name': 'PRINTED LINEN BLEND DRESS', 'price': '4,990 ALL'}, {'name': 'PRINTED LINEN BLEND DRESS', 'price': '32,900.00 AMD'}, {'name': 'PRINTED LINEN BLEND DRESS', 'price': '119.00 AZN'}, {'name': 'PRINTED LINEN BLEND DRESS', 'price': '85.95 BAM'}, {'name': 'PRINTED LINEN BLEND DRESS', 'price': '49.95 EUR'}, {'name': 'PRINTED LINEN BLEND DRESS', 'price': '89.95 лв'}, {'name': 'PRINTED LINEN BLEND DRESS', 'price': '29.90 BHD'}, {'name': 'LINEN BLEND PRINT DRESS', 'price': '79.90 CAD'}, {'name': 'PRINTED LINEN BLEND DRESS', 'price': '69.90 CHF'}, {'name': 'PRINTED LINEN BLEND DRESS', 'price': '¥ 399.00'}, {'name': 'LINEN BLEND PRINT DRESS', 'price': '249,000 COP'}, {'name': 'LINEN BLEND PRINT DRESS', 'price': '39,990 CRC'}, {'name': 'PRINTED LINEN BLEND DRESS', 'price': '49.95 EUR'}, {'name': 'PRINTED LINEN BLEND DRESS', 'price': '1,199 Kč'}, {'name': 'PRINTED LINEN BLEND DRESS', 'price': '49.95 EUR'}, {'name': 'PRINTED LINEN BLEND DRESS', 'price': '459.00 DKK'}, {'name': 'LINEN BLEND PRINT DRESS', 'price': '3,995 DOP'}, {'name': 'PRINTED LINEN BLEND DRESS', 'price': '9,900 DZD'}, {'name': 'PRINTED LINEN BLEND DRESS', 'price': '49.95 EUR'}, {'name': 'PRINTED LINEN BLEND DRESS', 'price': '1,199 EGP'}, {'name': 'PRINTED LINEN BLEND DRESS', 'price': '39.95 EUR'}, {'name': 'PRINTED LINEN BLEND DRESS', 'price': '49.95 EUR'}, {'name': 'PRINTED LINEN BLEND DRESS', 'price': '49.95 EUR'}, {'name': 'PRINTED LINEN BLEND DRESS', 'price': '169 GEL'}, {'name': 'PRINTED LINEN BLEND DRESS', 'price': '39.95 EUR'}, {'name': 'LINEN BLEND PRINT DRESS', 'price': '499.00 GTQ'}, {'name': 'PRINTED LINEN BLEND DRESS', 'price': 'HKD 499.00'}, {'name': 'LINEN BLEND PRINT DRESS', 'price': '1,495.00 HNL'}, {'name': 'PRINTED LINEN BLEND DRESS', 'price': '299.90 Kn'}, {'name': 'PRINTED LINEN BLEND DRESS', 'price': '15,995 Ft'}, {'name': 'PRINTED LINEN BLEND DRESS', 'price': '1,099,900 IDR'}, {'name': 'PRINTED LINEN BLEND DRESS', 'price': '49.95 EUR'}, {'name': 'PRINTED LINEN BLEND DRESS', 'price': '₪ 269.00'}, {'name': 'PRINTED LINEN BLEND DRESS', 'price': '₹ 4,990.00'}, {'name': 'PRINTED LINEN BLEND DRESS', 'price': '8,495 ISK'}, {'name': 'PRINTED LINEN BLEND DRESS', 'price': '49.95 EUR'}, {'name': 'PRINTED LINEN BLEND DRESS', 'price': '49.00 JOD'}, {'name': 'PRINTED LINEN BLEND DRESS', 'price': '7,590 JPY'}, {'name': 'PRINTED LINEN BLEND DRESS', 'price': '89,000 원'}, {'name': 'PRINTED LINEN BLEND DRESS', 'price': '25.90 KWD'}, {'name': 'PRINTED LINEN BLEND DRESS', 'price': '27,990.00 KZT'}, {'name': 'PRINTED LINEN BLEND DRESS', 'price': '1,599,000 LBP'}, {'name': 'PRINTED LINEN BLEND DRESS', 'price': '49.95 EUR'}, {'name': 'PRINTED LINEN BLEND DRESS', 'price': '49.95 EUR'}, {'name': 'PRINTED LINEN BLEND DRESS', 'price': '49.95 EUR'}, {'name': 'PRINTED LINEN BLEND DRESS', 'price': '699.00 MAD'}, {'name': 'PRINTED LINEN BLEND DRESS', 'price': '49.95 EUR'}, {'name': 'PRINTED LINEN BLEND DRESS', 'price': '39.95 EUR'}, {'name': 'PRINTED LINEN BLEND DRESS', 'price': '2,690.00 MKD'}, {'name': 'PRINTED LINEN BLEND DRESS', 'price': 'MOP 599.00'}, {'name': 'PRINTED LINEN BLEND DRESS', 'price': '49.95 EUR'}, {'name': 'LINEN BLEND PRINT DRESS', 'price': '1,299.00 MXN'}, {'name': 'PRINTED LINEN BLEND DRESS', 'price': '259.00 RM'}, {'name': 'PRINTED LINEN BLEND DRESS', 'price': '49.95 EUR'}, {'name': 'PRINTED LINEN BLEND DRESS', 'price': '599.00 NOK'}, {'name': 'PRINTED LINEN BLEND DRESS', 'price': '29.90 OMR'}, {'name': 'LINEN BLEND PRINT DRESS', 'price': '59.95 PAB'}, {'name': 'PRINTED LINEN BLEND DRESS', 'price': '3,295.00 PHP'}, {'name': 'PRINTED LINEN BLEND DRESS', 'price': '199.00 PLN'}, {'name': 'PRINTED LINEN BLEND DRESS', 'price': '39.95 EUR'}, {'name': 'PRINTED LINEN BLEND DRESS', 'price': '299.00 QAR'}, {'name': 'PRINTED LINEN BLEND DRESS', 'price': '199.90 lei'}, {'name': 'PRINTED LINEN BLEND DRESS', 'price': '4,990 RSD'}, {'name': 'PRIN ...

# %%
df=pd.DataFrame(dresslist)
print(df.head(15))
# Out:
#                          name          price
# 0   PRINTED LINEN BLEND DRESS      35.00 EUR
# 1   PRINTED LINEN BLEND DRESS     299.00 AED
# 2   PRINTED LINEN BLEND DRESS      4,990 ALL
# 3   PRINTED LINEN BLEND DRESS  32,900.00 AMD
# 4   PRINTED LINEN BLEND DRESS     119.00 AZN
# 5   PRINTED LINEN BLEND DRESS      85.95 BAM
# 6   PRINTED LINEN BLEND DRESS      49.95 EUR
# 7   PRINTED LINEN BLEND DRESS       89.95 лв
# 8   PRINTED LINEN BLEND DRESS      29.90 BHD
# 9     LINEN BLEND PRINT DRESS      79.90 CAD
# 10  PRINTED LINEN BLEND DRESS      69.90 CHF
# 11  PRINTED LINEN BLEND DRESS       ¥ 399.00
# 12    LINEN BLEND PRINT DRESS    249,000 COP
# 13    LINEN BLEND PRINT DRESS     39,990 CRC
# 14  PRINTED LINEN BLEND DRESS      49.95 EUR

# %%
print(df)
# Out:
#                          name          price
# 0   PRINTED LINEN BLEND DRESS      35.00 EUR
# 1   PRINTED LINEN BLEND DRESS     299.00 AED
# 2   PRINTED LINEN BLEND DRESS      4,990 ALL
# 3   PRINTED LINEN BLEND DRESS  32,900.00 AMD
# 4   PRINTED LINEN BLEND DRESS     119.00 AZN
# ..                        ...            ...
# 74  PRINTED LINEN BLEND DRESS      659.95 TL
# 75  PRINTED LINEN BLEND DRESS      NT$ 1,990
# 76  PRINTED LINEN BLEND DRESS   1,899.00 UAH
# 77  PRINTED LINEN BLEND DRESS      49.99 GBP
# 78    LINEN BLEND PRINT DRESS      69.90 USD
#
# [79 rows x 2 columns]

# %%
df.dtypes
# Out:
# name     object
# price    object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79 entries, 0 to 78
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    79 non-null     object
#  1   price   79 non-null     object
# dtypes: object(2)
# memory usage: 1.4+ KB

# %%
df.describe()
# Out:
#                              name      price
# count                          79         79
# unique                          2         61
# top     PRINTED LINEN BLEND DRESS  49.95 EUR
# freq                           69         14

# %%
alpha_2=countrylinks

# %%
for i in range(len(alpha_2)):
    alpha_2[i] = alpha_2[i].upper()

print(alpha_2)
# Out:
# ['AD', 'AE', 'AL', 'AM', 'AZ', 'BA', 'BE', 'BG', 'BH', 'CA', 'CH', 'CN', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EE', 'EG', 'ES', 'FI', 'FR', 'GE', 'GR', 'GT', 'HK', 'HN', 'HR', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KR', 'KW', 'KZ', 'LB', 'LT', 'LU', 'LV', 'MA', 'MC', 'ME', 'MK', 'MO', 'MT', 'MX', 'MY', 'NL', 'NO', 'OM', 'PA', 'PH', 'PL', 'PT', 'QA', 'RO', 'RS', 'RU', 'SA', 'SE', 'SG', 'SI', 'SK', 'SV', 'TH', 'TN', 'TR', 'TW', 'UA', 'UK', 'US']

# %%
for i in range(len(alpha_2)):
    if alpha_2[i] == 'UK':
        alpha_2[i] = 'GB'

# %%
countries = {}
for country in pycountry.countries:
    countries[country.alpha_2] = country.name

country_name = [countries.get(country, 'Unknown code') for country in alpha_2]

# %%
print(country_name)
# Out:
# ['Andorra', 'United Arab Emirates', 'Albania', 'Armenia', 'Azerbaijan', 'Bosnia and Herzegovina', 'Belgium', 'Bulgaria', 'Bahrain', 'Canada', 'Switzerland', 'China', 'Colombia', 'Costa Rica', 'Cyprus', 'Czechia', 'Germany', 'Denmark', 'Dominican Republic', 'Algeria', 'Estonia', 'Egypt', 'Spain', 'Finland', 'France', 'Georgia', 'Greece', 'Guatemala', 'Hong Kong', 'Honduras', 'Croatia', 'Hungary', 'Indonesia', 'Ireland', 'Israel', 'India', 'Iceland', 'Italy', 'Jordan', 'Japan', 'Korea, Republic of', 'Kuwait', 'Kazakhstan', 'Lebanon', 'Lithuania', 'Luxembourg', 'Latvia', 'Morocco', 'Monaco', 'Montenegro', 'North Macedonia', 'Macao', 'Malta', 'Mexico', 'Malaysia', 'Netherlands', 'Norway', 'Oman', 'Panama', 'Philippines', 'Poland', 'Portugal', 'Qatar', 'Romania', 'Serbia', 'Russian Federation', 'Saudi Arabia', 'Sweden', 'Singapore', 'Slovenia', 'Slovakia', 'El Salvador', 'Thailand', 'Tunisia', 'Turkey', 'Taiwan, Province of China', 'Ukraine', 'United Kingdom', 'United States']

# %%
countries_code_3 = {}
for country in pycountry.countries:
    countries_code_3[country.alpha_2] = country.alpha_3

codes_3 = [countries_code_3.get(country, 'Unknown code') for country in alpha_2]
print(codes_3)
# Out:
# ['AND', 'ARE', 'ALB', 'ARM', 'AZE', 'BIH', 'BEL', 'BGR', 'BHR', 'CAN', 'CHE', 'CHN', 'COL', 'CRI', 'CYP', 'CZE', 'DEU', 'DNK', 'DOM', 'DZA', 'EST', 'EGY', 'ESP', 'FIN', 'FRA', 'GEO', 'GRC', 'GTM', 'HKG', 'HND', 'HRV', 'HUN', 'IDN', 'IRL', 'ISR', 'IND', 'ISL', 'ITA', 'JOR', 'JPN', 'KOR', 'KWT', 'KAZ', 'LBN', 'LTU', 'LUX', 'LVA', 'MAR', 'MCO', 'MNE', 'MKD', 'MAC', 'MLT', 'MEX', 'MYS', 'NLD', 'NOR', 'OMN', 'PAN', 'PHL', 'POL', 'PRT', 'QAT', 'ROU', 'SRB', 'RUS', 'SAU', 'SWE', 'SGP', 'SVN', 'SVK', 'SLV', 'THA', 'TUN', 'TUR', 'TWN', 'UKR', 'GBR', 'USA']

# %%
currencies=['EUR','AED','ALL','AMD','AZN','BAM','EUR','BGN','BHD','CAD','CHF','CNY','COP','CRC','EUR','CZK','EUR','DKK','DOP','DZD','EUR','EGP','EUR','EUR','EUR','GEL','EUR','GTQ','HKD','HNL','HRK','HUF','IDR','EUR','ILS','INR','ISK','EUR','JOD','JPY','KRW','KWD','KZT','LBP','EUR','EUR','EUR','MAD','EUR','EUR','MKD','MOP','EUR','MXN','MYR','EUR','NOK','OMR','PAB','PHP','PLN','EUR','QAR','RON','RSD','RUB','SAR','SEK','SGD','EUR','EUR','USD','THB','TND','TRY','TWD','UAH','GBP','USD']

# %%
df['country_name']=country_name

# %%
df['country_code']=alpha_2

# %%
df['country_code_3']=codes_3

# %%
df['currency']=currencies

# %%
df['date']= np.datetime64('2022-05-02')

# %%
df['coleccion']='Spring2022'

# %%
df['realprice'] = df['price'].astype(str)

# %%
df['itemprice'] = df['realprice'].str.extract('(\d[\d,.]*)', expand=False).str.strip()

# %%
df.itemprice = df.itemprice.apply(lambda x : x.replace(',',''))

# %%
df['itemprice'] = pd.to_numeric(df['itemprice'])

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
print(df)
# Out:
#                          name          price               country_name  \
# 0   PRINTED LINEN BLEND DRESS      35.00 EUR                    Andorra
# 1   PRINTED LINEN BLEND DRESS     299.00 AED       United Arab Emirates
# 2   PRINTED LINEN BLEND DRESS      4,990 ALL                    Albania
# 3   PRINTED LINEN BLEND DRESS  32,900.00 AMD                    Armenia
# 4   PRINTED LINEN BLEND DRESS     119.00 AZN                 Azerbaijan
# 5   PRINTED LINEN BLEND DRESS      85.95 BAM     Bosnia and Herzegovina
# 6   PRINTED LINEN BLEND DRESS      49.95 EUR                    Belgium
# 7   PRINTED LINEN BLEND DRESS       89.95 лв                   Bulgaria
# 8   PRINTED LINEN BLEND DRESS      29.90 BHD                    Bahrain
# 9     LINEN BLEND PRINT DRESS      79.90 CAD                     Canada
# 10  PRINTED LINEN BLEND DRESS      69.90 CHF                Switzerland
# 11  PRINTED LINEN BLEND DRESS       ¥ 399.00                      China
# 12    LINEN BLEND PRINT DRESS    249,000 COP                   Colombia
# 13    LINEN BLEND PRINT DRESS     39,990 CRC                 Costa Rica
# 14  PRINTED LINEN BLEND DRESS      49.95 EUR                     Cyprus
# 15  PRINTED LINEN BLEND DRESS       1,199 Kč                    Czechia
# 16  PRINTED LINEN BLEND DRESS      49.95 EUR                    Germany
# 17  PRINTED LINEN BLEND DRESS     459.00 DKK                    Denmark
# 18    LINEN BLEND PRINT DRESS      3,995 DOP         Dominican Republic
# 19  PRINTED LINEN BLEND DRESS      9,900 DZD                    Algeria
# 20  PRINTED LINEN BLEND DRESS      49.95 EUR                    Estonia
# 21  PRINTED LINEN BLEND DRESS      1,199 EGP                      Egypt
# 22  PRINTED LINEN BLEND DRESS      39.95 EUR                      Spain
# 23  PRINTED LINEN BLEND DRESS      49.95 EUR                    Finland
# 24  PRINTED LINEN BLEND DRESS      49.95 EUR                     France
# 25  PRINTED LINEN BLEND DRESS        169 GEL                    Georgia
# 26  PRINTED LINEN BLEND DRESS      39.95 EUR                     Greece
# 27    LINEN BLEND PRINT DRESS     499.00 GTQ                  Guatemala
# 28  PRINTED LINEN BLEND DRESS     HKD 499.00                  Hong Kong
# 29    LINEN BLEND PRINT DRESS   1,495.00 HNL                   Honduras
# 30  PRINTED LINEN BLEND DRESS      299.90 Kn                    Croatia
# 31  PRINTED LINEN BLEND DRESS      15,995 Ft                    Hungary
# 32  PRINTED LINEN BLEND DRESS  1,099,900 IDR                  Indonesia
# 33  PRINTED LINEN BLEND DRESS      49.95 EUR                    Ireland
# 34  PRINTED LINEN BLEND DRESS       ₪ 269.00                     Israel
# 35  PRINTED LINEN BLEND DRESS     ₹ 4,990.00                      India
# 36  PRINTED LINEN BLEND DRESS      8,495 ISK                    Iceland
# 37  PRINTED LINEN BLEND DRESS      49.95 EUR                      Italy
# 38  PRINTED LINEN BLEND DRESS      49.00 JOD                     Jordan
# 39  PRINTED LINEN BLEND DRESS      7,590 JPY                      Japan
# 40  PRINTED LINEN BLEND DRESS       89,000 원         Korea, Republic of
# 41  PRINTED LINEN BLEND DRESS      25.90 KWD                     Kuwait
# 42  PRINTED LINEN BLEND DRESS  27,990.00 KZT                 Kazakhstan
# 43  PRINTED LINEN BLEND DRESS  1,599,000 LBP                    Lebanon
# 44  PRINTED LINEN BLEND DRESS      49.95 EUR                  Lithuania
# 45  PRINTED LINEN BLEND DRESS      49.95 EUR                 Luxembourg
# 46  PRINTED LINEN BLEND DRESS      49.95 EUR                     Latvia
# 47  PRINTED LINEN BLEND DRESS     699.00 MAD                    Morocco
# 48  PRINTED LINEN BLEND DRESS      49.95 EUR                     Monaco
# 49  PRINTED LINEN BLEND DRESS      39.95 EUR                 Montenegro
# 50  PRINTED LINEN BLEND DRESS   2,690.00 MKD            North Macedonia
# 51  PRINTED LINEN BLEND DRESS     MOP 599.00                      Macao
# 52  PRINTED LINEN BLEND DRESS      49.95 EUR                      Malta
# 53    LINEN BLEND PRINT DRESS   1,299.00 MXN                     Mexico
# 54  PRINTED LINEN BLEND DRESS      259.00 RM                   Malaysia
# 55  PRINTED LINEN BLEND DRESS      49.95 EUR                Netherlands
# 56  PRINTED LINEN BLEND DRESS     599.00 NOK                     Norway
# 57  PRINTED LINEN BLEND DRESS      29.90 OMR                       Oman
# 58    LINEN BLEND PRINT DRESS      59.95 PAB                     Panama
# 59  PRINTED LINEN BLEND DRESS   3,295.00 PHP                Philippines
# 60  PRINTED LINEN BLEND DRESS     199.00 PLN                     Poland
# 61  PRINTED LINEN BLEND DRESS      39.95 EUR                   Portugal
# 62  PRINTED LINEN BLEND DRESS     299.00 QAR                      Qatar
# 63  PRINTED LINEN BLEND DRESS     199.90 lei                    Romania
# 64  PRINTED LINEN BLEND DRESS      4,990 RSD                     Serbia
# 65  PRINTED LINEN BLEND DRESS     4,999 руб.         Russian Federation
# 66  PRINTED LINEN BLEND DRESS     329.00 SAR               Saudi Arabia
# 67  PRINTED LINEN BLEND DRESS     559.00 SEK                     Sweden
# 68  PRINTED LINEN BLEND DRESS       S$ 99.90                  Singapore
# 69  PRINTED LINEN BLEND DRESS      39.95 EUR                   Slovenia
# 70  PRINTED LINEN BLEND DRESS      39.95 EUR                   Slovakia
# 71    LINEN BLEND PRINT DRESS      65.95 USD                El Salvador
# 72  PRINTED LINEN BLEND DRESS      2,490 THB                   Thailand
# 73  PRINTED LINEN BLEND DRESS     199.00 TND                    Tunisia
# 74  PRINTED LINEN BLEND DRESS      659.95 TL                     Turkey
# 75  PRINTED LINEN BLEND DRESS      NT$ 1,990  Taiwan, Province of China
# 76  PRINTED LINEN BLEND DRESS   1,899.00 UAH                    Ukraine
# 77  PRINTED LINEN BLEND DRESS      49.99 GBP             United Kingdom
# 78    LINEN BLEND PRINT DRESS      69.90 USD              United States
#
#    country_code country_code_3 currency       date   coleccion      realprice  \
# 0            AD            AND      EUR 2022-05-02  Spring2022      35.00 EUR
# 1            AE            ARE      AED 2022-05-02  Spring2022     299.00 AED
# 2            AL            ALB      ALL 2022-05-02  Spring2022      4,990 ALL
# 3            AM            ARM      AMD 2022-05-02  Spring2022  32,900.00 AMD
# 4            AZ            AZE      AZN 2022-05-02  Spring2022     119.00 AZN
# 5            BA            BIH      BAM 2022-05-02  Spring2022      85.95 BAM
# 6            BE            BEL      EUR 2022-05-02  Spring2022      49.95 EUR
# 7            BG            BGR      BGN 2022-05-02  Spring2022       89.95 лв
# 8            BH            BHR      BHD 2022-05-02  Spring2022      29.90 BHD
# 9            CA            CAN      CAD 2022-05-02  Spring2022      79.90 CAD
# 10           CH            CHE      CHF 2022-05-02  Spring2022      69.90 CHF
# 11           CN            CHN      CNY 2022-05-02  Spring2022       ¥ 399.00
# 12           CO            COL      COP 2022-05-02  Spring2022    249,000 COP
# 13           CR            CRI      CRC 2022-05-02  Spring2022     39,990 CRC
# 14           CY            CYP      EUR 2022-05-02  Spring2022      49.95 EUR
# 15           CZ            CZE      CZK 2022-05-02  Spring2022       1,199 Kč
# 16           DE            DEU      EUR 2022-05-02  Spring2022      49.95 EUR
# 17           DK            DNK      DKK 2022-05-02  Spring2022     459.00 DKK
# 18           DO            DOM      DOP 2022-05-02  Spring2022      3,995 DOP
# 19           DZ            DZA      DZD 2022-05-02  Spring2022      9,900 DZD
# 20           EE            EST      EUR 2022-05-02  Spring2022      49.95 EUR
# 21           EG            EGY      EGP 2022-05-02  Spring2022      1,199 EGP
# 22           ES            ESP      EUR 2022-05-02  Spring2022      39.95 EUR
# 23           FI            FIN      EUR 2022-05-02  Spring2022      49.95 EUR
# 24           FR            FRA      EUR 2022-05-02  Spring2022      49.95 EUR
# 25           GE            GEO      GEL 2022-05-02  Spring2022        169 GEL
# 26           GR            GRC      EUR 2022-05-02  Spring2022      39.95 EUR
# 27           GT            GTM      GTQ 2022-05-02  Spring2022     499.00 GTQ
# 28           HK            HKG      HKD 2022-05-02  Spring2022     HKD 499.00
# 29           HN            HND      HNL 2022-05-02  Spring2022   1,495.00 HNL
# 30           HR            HRV      HRK 2022-05-02  Spring2022      299.90 Kn
# 31           HU            HUN      HUF 2022-05-02  Spring2022      15,995 Ft
# 32           ID            IDN      IDR 2022-05-02  Spring2022  1,099,900 IDR
# 33           IE            IRL      EUR 2022-05-02  Spring2022      49.95 EUR
# 34           IL            ISR      ILS 2022-05-02  Spring2022       ₪ 269.00
# 35           IN            IND      INR 2022-05-02  Spring2022     ₹ 4,990.00
# 36           IS            ISL      ISK 2022-05-02  Spring2022      8,495 ISK
# 37           IT            ITA      EUR 2022-05-02  Spring2022      49.95 EUR
# 38           JO            JOR      JOD 2022-05-02  Spring2022      49.00 JOD
# 39           JP            JPN      JPY 2022-05-02  Spring2022      7,590 JPY
# 40           KR            KOR      KRW 2022-05-02  Spring2022       89,000 원
# 41           KW            KWT      KWD 2022-05-02  Spring2022      25.90 KWD
# 42           KZ            KAZ      KZT 2022-05-02  Spring2022  27,990.00 KZT
# 43           LB            LBN      LBP 2022-05-02  Spring2022  1,599,000 LBP
# 44           LT            LTU      EUR 2022-05-02  Spring2022      49.95 EUR
# 45           LU            LUX      EUR 2022-05-02  Spring2022      49.95 EUR
# 46           LV            LVA      EUR 2022-05-02  Spring2022      49.95 EUR
# 47           MA            MAR      MAD 2022-05-02  Spring2022     699.00 MAD
# 48           MC            MCO      EUR 2022-05-02  Spring2022      49.95 EUR
# 49           ME            MNE      EUR 2022-05-02  Spring2022      39.95 EUR
# 50           MK            MKD      MKD 2022-05-02  Spring2022   2,690.00 MKD
# 51           MO            MAC      MOP 2022-05-02  Spring2022     MOP 599.00
# 52           MT            MLT      EUR 2022-05-02  Spring2022      49.95 EUR
# 53           MX            MEX      MXN 2022-05-02  Spring2022   1,299.00 MXN
# 54           MY            MYS      MYR 2022-05-02  Spring2022      259.00 RM
# 55           NL            NLD      EUR 2022-05-02  Spring2022      49.95 EUR
# 56           NO            NOR      NOK 2022-05-02  Spring2022     599.00 NOK
# 57           OM            OMN      OMR 2022-05-02  Spring2022      29.90 OMR
# 58           PA            PAN      PAB 2022-05-02  Spring2022      59.95 PAB
# 59           PH            PHL      PHP 2022-05-02  Spring2022   3,295.00 PHP
# 60           PL            POL      PLN 2022-05-02  Spring2022     199.00 PLN
# 61           PT            PRT      EUR 2022-05-02  Spring2022      39.95 EUR
# 62           QA            QAT      QAR 2022-05-02  Spring2022     299.00 QAR
# 63           RO            ROU      RON 2022-05-02  Spring2022     199.90 lei
# 64           RS            SRB      RSD 2022-05-02  Spring2022      4,990 RSD
# 65           RU            RUS      RUB 2022-05-02  Spring2022     4,999 руб.
# 66           SA            SAU      SAR 2022-05-02  Spring2022     329.00 SAR
# 67           SE            SWE      SEK 2022-05-02  Spring2022     559.00 SEK
# 68           SG            SGP      SGD 2022-05-02  Spring2022       S$ 99.90
# 69           SI            SVN      EUR 2022-05-02  Spring2022      39.95 EUR
# 70           SK            SVK      EUR 2022-05-02  Spring2022      39.95 EUR
# 71           SV            SLV      USD 2022-05-02  Spring2022      65.95 USD
# 72           TH            THA      THB 2022-05-02  Spring2022      2,490 THB
# 73           TN            TUN      TND 2022-05-02  Spring2022     199.00 TND
# 74           TR            TUR      TRY 2022-05-02  Spring2022      659.95 TL
# 75           TW            TWN      TWD 2022-05-02  Spring2022      NT$ 1,990
# 76           UA            UKR      UAH 2022-05-02  Spring2022   1,899.00 UAH
# 77           GB            GBR      GBP 2022-05-02  Spring2022      49.99 GBP
# 78           US            USA      USD 2022-05-02  Spring2022      69.90 USD
#
#      itemprice
# 0        35.00
# 1       299.00
# 2      4990.00
# 3     32900.00
# 4       119.00
# 5        85.95
# 6        49.95
# 7        89.95
# 8        29.90
# 9        79.90
# 10       69.90
# 11      399.00
# 12   249000.00
# 13    39990.00
# 14       49.95
# 15     1199.00
# 16       49.95
# 17      459.00
# 18     3995.00
# 19     9900.00
# 20       49.95
# 21     1199.00
# 22       39.95
# 23       49.95
# 24       49.95
# 25      169.00
# 26       39.95
# 27      499.00
# 28      499.00
# 29     1495.00
# 30      299.90
# 31    15995.00
# 32  1099900.00
# 33       49.95
# 34      269.00
# 35     4990.00
# 36     8495.00
# 37       49.95
# 38       49.00
# 39     7590.00
# 40    89000.00
# 41       25.90
# 42    27990.00
# 43  1599000.00
# 44       49.95
# 45       49.95
# 46       49.95
# 47      699.00
# 48       49.95
# 49       39.95
# 50     2690.00
# 51      599.00
# 52       49.95
# 53     1299.00
# 54      259.00
# 55       49.95
# 56      599.00
# 57       29.90
# 58       59.95
# 59     3295.00
# 60      199.00
# 61       39.95
# 62      299.00
# 63      199.90
# 64     4990.00
# 65     4999.00
# 66      329.00
# 67      559.00
# 68       99.90
# 69       39.95
# 70       39.95
# 71       65.95
# 72     2490.00
# 73      199.00
# 74      659.95
# 75     1990.00
# 76     1899.00
# 77       49.99
# 78       69.90

# %%
#!pip install pycountry

# %%
#!pip install forex_python

# %%
df['itemprice'] = df['itemprice'].astype('int')

# %%
df['date'] = df['date'].astype('datetime64[ns]')

# %%
df['itemprice'] = pd.to_numeric(df['itemprice'])

# %%
import requests

# Where USD is the base currency you want to use

url = 'https://openexchangerates.org/api/historical/2022-05-02.json?app_id=79098365fb7c423ebe0c094b93b9788e'


# Making our request
response = requests.get(url)
data = response.json()

# %%
rates=(data['rates'])
print(rates)
# Out:
# {'AED': 3.6731, 'AFN': 85.996512, 'ALL': 114.659201, 'AMD': 453.488078, 'ANG': 1.802984, 'AOA': 404.9645, 'ARS': 115.736615, 'AUD': 1.418269, 'AWG': 1.8, 'AZN': 1.7, 'BAM': 1.858818, 'BBD': 2, 'BDT': 86.72664, 'BGN': 1.860988, 'BHD': 0.37699, 'BIF': 2039.530777, 'BMD': 1, 'BND': 1.385885, 'BOB': 6.87794, 'BRL': 5.0861, 'BSD': 1, 'BTC': 2.5955692e-05, 'BTN': 76.439083, 'BWP': 12.112146, 'BYN': 3.366027, 'BZD': 2.016556, 'CAD': 1.28715, 'CDF': 2008.92093, 'CHF': 0.977657, 'CLF': 0.031213, 'CLP': 861.26, 'CNH': 6.67426, 'CNY': 6.6085, 'COP': 3963.950053, 'CRC': 661.990872, 'CUC': 1, 'CUP': 25.75, 'CVE': 105.15, 'CZK': 23.4998, 'DJF': 178.283759, 'DKK': 7.078502, 'DOP': 55.139832, 'DZD': 144.743339, 'EGP': 18.477713, 'ERN': 15.000001, 'ETB': 51.687589, 'EUR': 0.951506, 'FJD': 2.1835, 'FKP': 0.800057, 'GBP': 0.800057, 'GEL': 3.04, 'GGP': 0.800057, 'GHS': 7.517115, 'GIP': 0.800057, 'GMD': 54.075, 'GNF': 8850.938002, 'GTQ': 7.670763, 'GYD': 209.306262, 'HKD': 7.847955, 'HNL': 24.511089, 'HRK': 7.1944, 'HTG': 114.004138, 'HUF': 363.363771, 'IDR': 14526.6, 'ILS': 3.356805, 'IMP': 0.800057, 'INR': 76.52545, 'IQD': 1460.073454, 'IRR': 42250, 'ISK': 130.38, 'JEP': 0.800057, 'JMD': 154.38559, 'JOD': 0.709, 'JPY': 130.10575, 'KES': 115.849461, 'KGS': 82.300701, 'KHR': 4055.658358, 'KMF': 468.64997, 'KPW': 900, 'KRW': 1267.361827, 'KWD': 0.306637, 'KYD': 0.83369, 'KZT': 443.560722, 'LAK': 12391.773986, 'LBP': 1515.249084, 'LKR': 354.440069, 'LRD': 151.000001, 'LSL': 16.13, 'LYD': 4.791488, 'MAD': 10.0115, 'MDL': 18.43327, 'MGA': 4025.925895, 'MKD': 58.638794, 'MMK': 1852.36208, 'MNT': 3041.051599, 'MOP': 8.086166, 'MRU': 36.47, 'MUR': 42.694705, 'MVR': 15.45, 'MWK': 813.326152, 'MXN': 20.461808, 'MYR': 4.3535, 'MZN': 63.850001, 'NAD': 16.13, 'NGN': 415.189945, 'NIO': 35.810018, 'NOK': 9.440872, 'NPR': 122.303938, 'NZD': 1.552036, 'OMR': 0.384985, 'PAB': 1, 'PEN': 3.835, 'PGK': 3.521524, 'PHP': 52.545001, 'PKR': 185.7, 'PLN': 4.466278, 'PYG': 6821.94137, 'QAR': 3.641, 'RON': 4.7075, 'RSD': 111.584743, 'RUB': 70.7, 'RWF': 1020.5576, 'SAR': 3.75088, 'SBD': 8.028936, 'SCR': 12.934291, 'SDG': 447.5, 'SEK': 9.911338, 'SGD': 1.385695, 'SHP': 0.800057, 'SLL': 13305.098286, 'SOS': 578.815857, 'SRD': 20.821, 'SSP': 130.26, 'STD': 21973.540504, 'STN': 23.55, 'SVC': 8.753172, 'SYP': 2512.45, 'SZL': 15.856736, 'THB': 34.470863, 'TJS': 12.490769, 'TMT': 3.51, 'TND': 3.064, 'TOP': 2.314707, 'TRY': 14.8904, 'TTD': 6.792975, 'TWD': 29.5012, 'TZS': 2325, 'UAH': 29.412465, 'UGX': 3556.467781, 'USD': 1, 'UYU': 40.839121, 'UZS': 11179.146223, 'VES': 4.49615, 'VND': 22963.5, 'VUV': 113.695826, 'WST': 2.613371, 'XAF': 624.146711, 'XAG': 0.04416279, 'XAU': 0.00053669, 'XCD': 2.70255, 'XDR': 0.730292, 'XOF': 624.146711, 'XPD': 0.00045138, 'XPF': 113.544812, 'XPT': 0.00106513, 'YER': 250.249937, 'ZAR': 16.11894, 'ZMW': 17.038083, 'ZWL': 322}

# %%
pt = pd.DataFrame(list(rates.items()),columns = ['currency','rate']) 

print(pt)
# Out:
#     currency          rate
# 0        AED      3.673100
# 1        AFN     85.996512
# 2        ALL    114.659201
# 3        AMD    453.488078
# 4        ANG      1.802984
# 5        AOA    404.964500
# 6        ARS    115.736615
# 7        AUD      1.418269
# 8        AWG      1.800000
# 9        AZN      1.700000
# 10       BAM      1.858818
# 11       BBD      2.000000
# 12       BDT     86.726640
# 13       BGN      1.860988
# 14       BHD      0.376990
# 15       BIF   2039.530777
# 16       BMD      1.000000
# 17       BND      1.385885
# 18       BOB      6.877940
# 19       BRL      5.086100
# 20       BSD      1.000000
# 21       BTC      0.000026
# 22       BTN     76.439083
# 23       BWP     12.112146
# 24       BYN      3.366027
# 25       BZD      2.016556
# 26       CAD      1.287150
# 27       CDF   2008.920930
# 28       CHF      0.977657
# 29       CLF      0.031213
# 30       CLP    861.260000
# 31       CNH      6.674260
# 32       CNY      6.608500
# 33       COP   3963.950053
# 34       CRC    661.990872
# 35       CUC      1.000000
# 36       CUP     25.750000
# 37       CVE    105.150000
# 38       CZK     23.499800
# 39       DJF    178.283759
# 40       DKK      7.078502
# 41       DOP     55.139832
# 42       DZD    144.743339
# 43       EGP     18.477713
# 44       ERN     15.000001
# 45       ETB     51.687589
# 46       EUR      0.951506
# 47       FJD      2.183500
# 48       FKP      0.800057
# 49       GBP      0.800057
# 50       GEL      3.040000
# 51       GGP      0.800057
# 52       GHS      7.517115
# 53       GIP      0.800057
# 54       GMD     54.075000
# 55       GNF   8850.938002
# 56       GTQ      7.670763
# 57       GYD    209.306262
# 58       HKD      7.847955
# 59       HNL     24.511089
# 60       HRK      7.194400
# 61       HTG    114.004138
# 62       HUF    363.363771
# 63       IDR  14526.600000
# 64       ILS      3.356805
# 65       IMP      0.800057
# 66       INR     76.525450
# 67       IQD   1460.073454
# 68       IRR  42250.000000
# 69       ISK    130.380000
# 70       JEP      0.800057
# 71       JMD    154.385590
# 72       JOD      0.709000
# 73       JPY    130.105750
# 74       KES    115.849461
# 75       KGS     82.300701
# 76       KHR   4055.658358
# 77       KMF    468.649970
# 78       KPW    900.000000
# 79       KRW   1267.361827
# 80       KWD      0.306637
# 81       KYD      0.833690
# 82       KZT    443.560722
# 83       LAK  12391.773986
# 84       LBP   1515.249084
# 85       LKR    354.440069
# 86       LRD    151.000001
# 87       LSL     16.130000
# 88       LYD      4.791488
# 89       MAD     10.011500
# 90       MDL     18.433270
# 91       MGA   4025.925895
# 92       MKD     58.638794
# 93       MMK   1852.362080
# 94       MNT   3041.051599
# 95       MOP      8.086166
# 96       MRU     36.470000
# 97       MUR     42.694705
# 98       MVR     15.450000
# 99       MWK    813.326152
# 100      MXN     20.461808
# 101      MYR      4.353500
# 102      MZN     63.850001
# 103      NAD     16.130000
# 104      NGN    415.189945
# 105      NIO     35.810018
# 106      NOK      9.440872
# 107      NPR    122.303938
# 108      NZD      1.552036
# 109      OMR      0.384985
# 110      PAB      1.000000
# 111      PEN      3.835000
# 112      PGK      3.521524
# 113      PHP     52.545001
# 114      PKR    185.700000
# 115      PLN      4.466278
# 116      PYG   6821.941370
# 117      QAR      3.641000
# 118      RON      4.707500
# 119      RSD    111.584743
# 120      RUB     70.700000
# 121      RWF   1020.557600
# 122      SAR      3.750880
# 123      SBD      8.028936
# 124      SCR     12.934291
# 125      SDG    447.500000
# 126      SEK      9.911338
# 127      SGD      1.385695
# 128      SHP      0.800057
# 129      SLL  13305.098286
# 130      SOS    578.815857
# 131      SRD     20.821000
# 132      SSP    130.260000
# 133      STD  21973.540504
# 134      STN     23.550000
# 135      SVC      8.753172
# 136      SYP   2512.450000
# 137      SZL     15.856736
# 138      THB     34.470863
# 139      TJS     12.490769
# 140      TMT      3.510000
# 141      TND      3.064000
# 142      TOP      2.314707
# 143      TRY     14.890400
# 144      TTD      6.792975
# 145      TWD     29.501200
# 146      TZS   2325.000000
# 147      UAH     29.412465
# 148      UGX   3556.467781
# 149      USD      1.000000
# 150      UYU     40.839121
# 151      UZS  11179.146223
# 152      VES      4.496150
# 153      VND  22963.500000
# 154      VUV    113.695826
# 155      WST      2.613371
# 156      XAF    624.146711
# 157      XAG      0.044163
# 158      XAU      0.000537
# 159      XCD      2.702550
# 160      XDR      0.730292
# 161      XOF    624.146711
# 162      XPD      0.000451
# 163      XPF    113.544812
# 164      XPT      0.001065
# 165      YER    250.249937
# 166      ZAR     16.118940
# 167      ZMW     17.038083
# 168      ZWL    322.000000

# %%
df=df.merge(pt, on='currency', how='left')
print(df)
# Out:
#                          name          price               country_name  \
# 0   PRINTED LINEN BLEND DRESS      35.00 EUR                    Andorra
# 1   PRINTED LINEN BLEND DRESS     299.00 AED       United Arab Emirates
# 2   PRINTED LINEN BLEND DRESS      4,990 ALL                    Albania
# 3   PRINTED LINEN BLEND DRESS  32,900.00 AMD                    Armenia
# 4   PRINTED LINEN BLEND DRESS     119.00 AZN                 Azerbaijan
# 5   PRINTED LINEN BLEND DRESS      85.95 BAM     Bosnia and Herzegovina
# 6   PRINTED LINEN BLEND DRESS      49.95 EUR                    Belgium
# 7   PRINTED LINEN BLEND DRESS       89.95 лв                   Bulgaria
# 8   PRINTED LINEN BLEND DRESS      29.90 BHD                    Bahrain
# 9     LINEN BLEND PRINT DRESS      79.90 CAD                     Canada
# 10  PRINTED LINEN BLEND DRESS      69.90 CHF                Switzerland
# 11  PRINTED LINEN BLEND DRESS       ¥ 399.00                      China
# 12    LINEN BLEND PRINT DRESS    249,000 COP                   Colombia
# 13    LINEN BLEND PRINT DRESS     39,990 CRC                 Costa Rica
# 14  PRINTED LINEN BLEND DRESS      49.95 EUR                     Cyprus
# 15  PRINTED LINEN BLEND DRESS       1,199 Kč                    Czechia
# 16  PRINTED LINEN BLEND DRESS      49.95 EUR                    Germany
# 17  PRINTED LINEN BLEND DRESS     459.00 DKK                    Denmark
# 18    LINEN BLEND PRINT DRESS      3,995 DOP         Dominican Republic
# 19  PRINTED LINEN BLEND DRESS      9,900 DZD                    Algeria
# 20  PRINTED LINEN BLEND DRESS      49.95 EUR                    Estonia
# 21  PRINTED LINEN BLEND DRESS      1,199 EGP                      Egypt
# 22  PRINTED LINEN BLEND DRESS      39.95 EUR                      Spain
# 23  PRINTED LINEN BLEND DRESS      49.95 EUR                    Finland
# 24  PRINTED LINEN BLEND DRESS      49.95 EUR                     France
# 25  PRINTED LINEN BLEND DRESS        169 GEL                    Georgia
# 26  PRINTED LINEN BLEND DRESS      39.95 EUR                     Greece
# 27    LINEN BLEND PRINT DRESS     499.00 GTQ                  Guatemala
# 28  PRINTED LINEN BLEND DRESS     HKD 499.00                  Hong Kong
# 29    LINEN BLEND PRINT DRESS   1,495.00 HNL                   Honduras
# 30  PRINTED LINEN BLEND DRESS      299.90 Kn                    Croatia
# 31  PRINTED LINEN BLEND DRESS      15,995 Ft                    Hungary
# 32  PRINTED LINEN BLEND DRESS  1,099,900 IDR                  Indonesia
# 33  PRINTED LINEN BLEND DRESS      49.95 EUR                    Ireland
# 34  PRINTED LINEN BLEND DRESS       ₪ 269.00                     Israel
# 35  PRINTED LINEN BLEND DRESS     ₹ 4,990.00                      India
# 36  PRINTED LINEN BLEND DRESS      8,495 ISK                    Iceland
# 37  PRINTED LINEN BLEND DRESS      49.95 EUR                      Italy
# 38  PRINTED LINEN BLEND DRESS      49.00 JOD                     Jordan
# 39  PRINTED LINEN BLEND DRESS      7,590 JPY                      Japan
# 40  PRINTED LINEN BLEND DRESS       89,000 원         Korea, Republic of
# 41  PRINTED LINEN BLEND DRESS      25.90 KWD                     Kuwait
# 42  PRINTED LINEN BLEND DRESS  27,990.00 KZT                 Kazakhstan
# 43  PRINTED LINEN BLEND DRESS  1,599,000 LBP                    Lebanon
# 44  PRINTED LINEN BLEND DRESS      49.95 EUR                  Lithuania
# 45  PRINTED LINEN BLEND DRESS      49.95 EUR                 Luxembourg
# 46  PRINTED LINEN BLEND DRESS      49.95 EUR                     Latvia
# 47  PRINTED LINEN BLEND DRESS     699.00 MAD                    Morocco
# 48  PRINTED LINEN BLEND DRESS      49.95 EUR                     Monaco
# 49  PRINTED LINEN BLEND DRESS      39.95 EUR                 Montenegro
# 50  PRINTED LINEN BLEND DRESS   2,690.00 MKD            North Macedonia
# 51  PRINTED LINEN BLEND DRESS     MOP 599.00                      Macao
# 52  PRINTED LINEN BLEND DRESS      49.95 EUR                      Malta
# 53    LINEN BLEND PRINT DRESS   1,299.00 MXN                     Mexico
# 54  PRINTED LINEN BLEND DRESS      259.00 RM                   Malaysia
# 55  PRINTED LINEN BLEND DRESS      49.95 EUR                Netherlands
# 56  PRINTED LINEN BLEND DRESS     599.00 NOK                     Norway
# 57  PRINTED LINEN BLEND DRESS      29.90 OMR                       Oman
# 58    LINEN BLEND PRINT DRESS      59.95 PAB                     Panama
# 59  PRINTED LINEN BLEND DRESS   3,295.00 PHP                Philippines
# 60  PRINTED LINEN BLEND DRESS     199.00 PLN                     Poland
# 61  PRINTED LINEN BLEND DRESS      39.95 EUR                   Portugal
# 62  PRINTED LINEN BLEND DRESS     299.00 QAR                      Qatar
# 63  PRINTED LINEN BLEND DRESS     199.90 lei                    Romania
# 64  PRINTED LINEN BLEND DRESS      4,990 RSD                     Serbia
# 65  PRINTED LINEN BLEND DRESS     4,999 руб.         Russian Federation
# 66  PRINTED LINEN BLEND DRESS     329.00 SAR               Saudi Arabia
# 67  PRINTED LINEN BLEND DRESS     559.00 SEK                     Sweden
# 68  PRINTED LINEN BLEND DRESS       S$ 99.90                  Singapore
# 69  PRINTED LINEN BLEND DRESS      39.95 EUR                   Slovenia
# 70  PRINTED LINEN BLEND DRESS      39.95 EUR                   Slovakia
# 71    LINEN BLEND PRINT DRESS      65.95 USD                El Salvador
# 72  PRINTED LINEN BLEND DRESS      2,490 THB                   Thailand
# 73  PRINTED LINEN BLEND DRESS     199.00 TND                    Tunisia
# 74  PRINTED LINEN BLEND DRESS      659.95 TL                     Turkey
# 75  PRINTED LINEN BLEND DRESS      NT$ 1,990  Taiwan, Province of China
# 76  PRINTED LINEN BLEND DRESS   1,899.00 UAH                    Ukraine
# 77  PRINTED LINEN BLEND DRESS      49.99 GBP             United Kingdom
# 78    LINEN BLEND PRINT DRESS      69.90 USD              United States
#
#    country_code country_code_3 currency       date   coleccion      realprice  \
# 0            AD            AND      EUR 2022-05-02  Spring2022      35.00 EUR
# 1            AE            ARE      AED 2022-05-02  Spring2022     299.00 AED
# 2            AL            ALB      ALL 2022-05-02  Spring2022      4,990 ALL
# 3            AM            ARM      AMD 2022-05-02  Spring2022  32,900.00 AMD
# 4            AZ            AZE      AZN 2022-05-02  Spring2022     119.00 AZN
# 5            BA            BIH      BAM 2022-05-02  Spring2022      85.95 BAM
# 6            BE            BEL      EUR 2022-05-02  Spring2022      49.95 EUR
# 7            BG            BGR      BGN 2022-05-02  Spring2022       89.95 лв
# 8            BH            BHR      BHD 2022-05-02  Spring2022      29.90 BHD
# 9            CA            CAN      CAD 2022-05-02  Spring2022      79.90 CAD
# 10           CH            CHE      CHF 2022-05-02  Spring2022      69.90 CHF
# 11           CN            CHN      CNY 2022-05-02  Spring2022       ¥ 399.00
# 12           CO            COL      COP 2022-05-02  Spring2022    249,000 COP
# 13           CR            CRI      CRC 2022-05-02  Spring2022     39,990 CRC
# 14           CY            CYP      EUR 2022-05-02  Spring2022      49.95 EUR
# 15           CZ            CZE      CZK 2022-05-02  Spring2022       1,199 Kč
# 16           DE            DEU      EUR 2022-05-02  Spring2022      49.95 EUR
# 17           DK            DNK      DKK 2022-05-02  Spring2022     459.00 DKK
# 18           DO            DOM      DOP 2022-05-02  Spring2022      3,995 DOP
# 19           DZ            DZA      DZD 2022-05-02  Spring2022      9,900 DZD
# 20           EE            EST      EUR 2022-05-02  Spring2022      49.95 EUR
# 21           EG            EGY      EGP 2022-05-02  Spring2022      1,199 EGP
# 22           ES            ESP      EUR 2022-05-02  Spring2022      39.95 EUR
# 23           FI            FIN      EUR 2022-05-02  Spring2022      49.95 EUR
# 24           FR            FRA      EUR 2022-05-02  Spring2022      49.95 EUR
# 25           GE            GEO      GEL 2022-05-02  Spring2022        169 GEL
# 26           GR            GRC      EUR 2022-05-02  Spring2022      39.95 EUR
# 27           GT            GTM      GTQ 2022-05-02  Spring2022     499.00 GTQ
# 28           HK            HKG      HKD 2022-05-02  Spring2022     HKD 499.00
# 29           HN            HND      HNL 2022-05-02  Spring2022   1,495.00 HNL
# 30           HR            HRV      HRK 2022-05-02  Spring2022      299.90 Kn
# 31           HU            HUN      HUF 2022-05-02  Spring2022      15,995 Ft
# 32           ID            IDN      IDR 2022-05-02  Spring2022  1,099,900 IDR
# 33           IE            IRL      EUR 2022-05-02  Spring2022      49.95 EUR
# 34           IL            ISR      ILS 2022-05-02  Spring2022       ₪ 269.00
# 35           IN            IND      INR 2022-05-02  Spring2022     ₹ 4,990.00
# 36           IS            ISL      ISK 2022-05-02  Spring2022      8,495 ISK
# 37           IT            ITA      EUR 2022-05-02  Spring2022      49.95 EUR
# 38           JO            JOR      JOD 2022-05-02  Spring2022      49.00 JOD
# 39           JP            JPN      JPY 2022-05-02  Spring2022      7,590 JPY
# 40           KR            KOR      KRW 2022-05-02  Spring2022       89,000 원
# 41           KW            KWT      KWD 2022-05-02  Spring2022      25.90 KWD
# 42           KZ            KAZ      KZT 2022-05-02  Spring2022  27,990.00 KZT
# 43           LB            LBN      LBP 2022-05-02  Spring2022  1,599,000 LBP
# 44           LT            LTU      EUR 2022-05-02  Spring2022      49.95 EUR
# 45           LU            LUX      EUR 2022-05-02  Spring2022      49.95 EUR
# 46           LV            LVA      EUR 2022-05-02  Spring2022      49.95 EUR
# 47           MA            MAR      MAD 2022-05-02  Spring2022     699.00 MAD
# 48           MC            MCO      EUR 2022-05-02  Spring2022      49.95 EUR
# 49           ME            MNE      EUR 2022-05-02  Spring2022      39.95 EUR
# 50           MK            MKD      MKD 2022-05-02  Spring2022   2,690.00 MKD
# 51           MO            MAC      MOP 2022-05-02  Spring2022     MOP 599.00
# 52           MT            MLT      EUR 2022-05-02  Spring2022      49.95 EUR
# 53           MX            MEX      MXN 2022-05-02  Spring2022   1,299.00 MXN
# 54           MY            MYS      MYR 2022-05-02  Spring2022      259.00 RM
# 55           NL            NLD      EUR 2022-05-02  Spring2022      49.95 EUR
# 56           NO            NOR      NOK 2022-05-02  Spring2022     599.00 NOK
# 57           OM            OMN      OMR 2022-05-02  Spring2022      29.90 OMR
# 58           PA            PAN      PAB 2022-05-02  Spring2022      59.95 PAB
# 59           PH            PHL      PHP 2022-05-02  Spring2022   3,295.00 PHP
# 60           PL            POL      PLN 2022-05-02  Spring2022     199.00 PLN
# 61           PT            PRT      EUR 2022-05-02  Spring2022      39.95 EUR
# 62           QA            QAT      QAR 2022-05-02  Spring2022     299.00 QAR
# 63           RO            ROU      RON 2022-05-02  Spring2022     199.90 lei
# 64           RS            SRB      RSD 2022-05-02  Spring2022      4,990 RSD
# 65           RU            RUS      RUB 2022-05-02  Spring2022     4,999 руб.
# 66           SA            SAU      SAR 2022-05-02  Spring2022     329.00 SAR
# 67           SE            SWE      SEK 2022-05-02  Spring2022     559.00 SEK
# 68           SG            SGP      SGD 2022-05-02  Spring2022       S$ 99.90
# 69           SI            SVN      EUR 2022-05-02  Spring2022      39.95 EUR
# 70           SK            SVK      EUR 2022-05-02  Spring2022      39.95 EUR
# 71           SV            SLV      USD 2022-05-02  Spring2022      65.95 USD
# 72           TH            THA      THB 2022-05-02  Spring2022      2,490 THB
# 73           TN            TUN      TND 2022-05-02  Spring2022     199.00 TND
# 74           TR            TUR      TRY 2022-05-02  Spring2022      659.95 TL
# 75           TW            TWN      TWD 2022-05-02  Spring2022      NT$ 1,990
# 76           UA            UKR      UAH 2022-05-02  Spring2022   1,899.00 UAH
# 77           GB            GBR      GBP 2022-05-02  Spring2022      49.99 GBP
# 78           US            USA      USD 2022-05-02  Spring2022      69.90 USD
#
#     itemprice          rate
# 0          35      0.951506
# 1         299      3.673100
# 2        4990    114.659201
# 3       32900    453.488078
# 4         119      1.700000
# 5          85      1.858818
# 6          49      0.951506
# 7          89      1.860988
# 8          29      0.376990
# 9          79      1.287150
# 10         69      0.977657
# 11        399      6.608500
# 12     249000   3963.950053
# 13      39990    661.990872
# 14         49      0.951506
# 15       1199     23.499800
# 16         49      0.951506
# 17        459      7.078502
# 18       3995     55.139832
# 19       9900    144.743339
# 20         49      0.951506
# 21       1199     18.477713
# 22         39      0.951506
# 23         49      0.951506
# 24         49      0.951506
# 25        169      3.040000
# 26         39      0.951506
# 27        499      7.670763
# 28        499      7.847955
# 29       1495     24.511089
# 30        299      7.194400
# 31      15995    363.363771
# 32    1099900  14526.600000
# 33         49      0.951506
# 34        269      3.356805
# 35       4990     76.525450
# 36       8495    130.380000
# 37         49      0.951506
# 38         49      0.709000
# 39       7590    130.105750
# 40      89000   1267.361827
# 41         25      0.306637
# 42      27990    443.560722
# 43    1599000   1515.249084
# 44         49      0.951506
# 45         49      0.951506
# 46         49      0.951506
# 47        699     10.011500
# 48         49      0.951506
# 49         39      0.951506
# 50       2690     58.638794
# 51        599      8.086166
# 52         49      0.951506
# 53       1299     20.461808
# 54        259      4.353500
# 55         49      0.951506
# 56        599      9.440872
# 57         29      0.384985
# 58         59      1.000000
# 59       3295     52.545001
# 60        199      4.466278
# 61         39      0.951506
# 62        299      3.641000
# 63        199      4.707500
# 64       4990    111.584743
# 65       4999     70.700000
# 66        329      3.750880
# 67        559      9.911338
# 68         99      1.385695
# 69         39      0.951506
# 70         39      0.951506
# 71         65      1.000000
# 72       2490     34.470863
# 73        199      3.064000
# 74        659     14.890400
# 75       1990     29.501200
# 76       1899     29.412465
# 77         49      0.800057
# 78         69      1.000000

# %%
df['price_USD']=df['itemprice']/df['rate']

# %%
print(df)
# Out:
#                          name          price               country_name  \
# 0   PRINTED LINEN BLEND DRESS      35.00 EUR                    Andorra
# 1   PRINTED LINEN BLEND DRESS     299.00 AED       United Arab Emirates
# 2   PRINTED LINEN BLEND DRESS      4,990 ALL                    Albania
# 3   PRINTED LINEN BLEND DRESS  32,900.00 AMD                    Armenia
# 4   PRINTED LINEN BLEND DRESS     119.00 AZN                 Azerbaijan
# 5   PRINTED LINEN BLEND DRESS      85.95 BAM     Bosnia and Herzegovina
# 6   PRINTED LINEN BLEND DRESS      49.95 EUR                    Belgium
# 7   PRINTED LINEN BLEND DRESS       89.95 лв                   Bulgaria
# 8   PRINTED LINEN BLEND DRESS      29.90 BHD                    Bahrain
# 9     LINEN BLEND PRINT DRESS      79.90 CAD                     Canada
# 10  PRINTED LINEN BLEND DRESS      69.90 CHF                Switzerland
# 11  PRINTED LINEN BLEND DRESS       ¥ 399.00                      China
# 12    LINEN BLEND PRINT DRESS    249,000 COP                   Colombia
# 13    LINEN BLEND PRINT DRESS     39,990 CRC                 Costa Rica
# 14  PRINTED LINEN BLEND DRESS      49.95 EUR                     Cyprus
# 15  PRINTED LINEN BLEND DRESS       1,199 Kč                    Czechia
# 16  PRINTED LINEN BLEND DRESS      49.95 EUR                    Germany
# 17  PRINTED LINEN BLEND DRESS     459.00 DKK                    Denmark
# 18    LINEN BLEND PRINT DRESS      3,995 DOP         Dominican Republic
# 19  PRINTED LINEN BLEND DRESS      9,900 DZD                    Algeria
# 20  PRINTED LINEN BLEND DRESS      49.95 EUR                    Estonia
# 21  PRINTED LINEN BLEND DRESS      1,199 EGP                      Egypt
# 22  PRINTED LINEN BLEND DRESS      39.95 EUR                      Spain
# 23  PRINTED LINEN BLEND DRESS      49.95 EUR                    Finland
# 24  PRINTED LINEN BLEND DRESS      49.95 EUR                     France
# 25  PRINTED LINEN BLEND DRESS        169 GEL                    Georgia
# 26  PRINTED LINEN BLEND DRESS      39.95 EUR                     Greece
# 27    LINEN BLEND PRINT DRESS     499.00 GTQ                  Guatemala
# 28  PRINTED LINEN BLEND DRESS     HKD 499.00                  Hong Kong
# 29    LINEN BLEND PRINT DRESS   1,495.00 HNL                   Honduras
# 30  PRINTED LINEN BLEND DRESS      299.90 Kn                    Croatia
# 31  PRINTED LINEN BLEND DRESS      15,995 Ft                    Hungary
# 32  PRINTED LINEN BLEND DRESS  1,099,900 IDR                  Indonesia
# 33  PRINTED LINEN BLEND DRESS      49.95 EUR                    Ireland
# 34  PRINTED LINEN BLEND DRESS       ₪ 269.00                     Israel
# 35  PRINTED LINEN BLEND DRESS     ₹ 4,990.00                      India
# 36  PRINTED LINEN BLEND DRESS      8,495 ISK                    Iceland
# 37  PRINTED LINEN BLEND DRESS      49.95 EUR                      Italy
# 38  PRINTED LINEN BLEND DRESS      49.00 JOD                     Jordan
# 39  PRINTED LINEN BLEND DRESS      7,590 JPY                      Japan
# 40  PRINTED LINEN BLEND DRESS       89,000 원         Korea, Republic of
# 41  PRINTED LINEN BLEND DRESS      25.90 KWD                     Kuwait
# 42  PRINTED LINEN BLEND DRESS  27,990.00 KZT                 Kazakhstan
# 43  PRINTED LINEN BLEND DRESS  1,599,000 LBP                    Lebanon
# 44  PRINTED LINEN BLEND DRESS      49.95 EUR                  Lithuania
# 45  PRINTED LINEN BLEND DRESS      49.95 EUR                 Luxembourg
# 46  PRINTED LINEN BLEND DRESS      49.95 EUR                     Latvia
# 47  PRINTED LINEN BLEND DRESS     699.00 MAD                    Morocco
# 48  PRINTED LINEN BLEND DRESS      49.95 EUR                     Monaco
# 49  PRINTED LINEN BLEND DRESS      39.95 EUR                 Montenegro
# 50  PRINTED LINEN BLEND DRESS   2,690.00 MKD            North Macedonia
# 51  PRINTED LINEN BLEND DRESS     MOP 599.00                      Macao
# 52  PRINTED LINEN BLEND DRESS      49.95 EUR                      Malta
# 53    LINEN BLEND PRINT DRESS   1,299.00 MXN                     Mexico
# 54  PRINTED LINEN BLEND DRESS      259.00 RM                   Malaysia
# 55  PRINTED LINEN BLEND DRESS      49.95 EUR                Netherlands
# 56  PRINTED LINEN BLEND DRESS     599.00 NOK                     Norway
# 57  PRINTED LINEN BLEND DRESS      29.90 OMR                       Oman
# 58    LINEN BLEND PRINT DRESS      59.95 PAB                     Panama
# 59  PRINTED LINEN BLEND DRESS   3,295.00 PHP                Philippines
# 60  PRINTED LINEN BLEND DRESS     199.00 PLN                     Poland
# 61  PRINTED LINEN BLEND DRESS      39.95 EUR                   Portugal
# 62  PRINTED LINEN BLEND DRESS     299.00 QAR                      Qatar
# 63  PRINTED LINEN BLEND DRESS     199.90 lei                    Romania
# 64  PRINTED LINEN BLEND DRESS      4,990 RSD                     Serbia
# 65  PRINTED LINEN BLEND DRESS     4,999 руб.         Russian Federation
# 66  PRINTED LINEN BLEND DRESS     329.00 SAR               Saudi Arabia
# 67  PRINTED LINEN BLEND DRESS     559.00 SEK                     Sweden
# 68  PRINTED LINEN BLEND DRESS       S$ 99.90                  Singapore
# 69  PRINTED LINEN BLEND DRESS      39.95 EUR                   Slovenia
# 70  PRINTED LINEN BLEND DRESS      39.95 EUR                   Slovakia
# 71    LINEN BLEND PRINT DRESS      65.95 USD                El Salvador
# 72  PRINTED LINEN BLEND DRESS      2,490 THB                   Thailand
# 73  PRINTED LINEN BLEND DRESS     199.00 TND                    Tunisia
# 74  PRINTED LINEN BLEND DRESS      659.95 TL                     Turkey
# 75  PRINTED LINEN BLEND DRESS      NT$ 1,990  Taiwan, Province of China
# 76  PRINTED LINEN BLEND DRESS   1,899.00 UAH                    Ukraine
# 77  PRINTED LINEN BLEND DRESS      49.99 GBP             United Kingdom
# 78    LINEN BLEND PRINT DRESS      69.90 USD              United States
#
#    country_code country_code_3 currency       date   coleccion      realprice  \
# 0            AD            AND      EUR 2022-05-02  Spring2022      35.00 EUR
# 1            AE            ARE      AED 2022-05-02  Spring2022     299.00 AED
# 2            AL            ALB      ALL 2022-05-02  Spring2022      4,990 ALL
# 3            AM            ARM      AMD 2022-05-02  Spring2022  32,900.00 AMD
# 4            AZ            AZE      AZN 2022-05-02  Spring2022     119.00 AZN
# 5            BA            BIH      BAM 2022-05-02  Spring2022      85.95 BAM
# 6            BE            BEL      EUR 2022-05-02  Spring2022      49.95 EUR
# 7            BG            BGR      BGN 2022-05-02  Spring2022       89.95 лв
# 8            BH            BHR      BHD 2022-05-02  Spring2022      29.90 BHD
# 9            CA            CAN      CAD 2022-05-02  Spring2022      79.90 CAD
# 10           CH            CHE      CHF 2022-05-02  Spring2022      69.90 CHF
# 11           CN            CHN      CNY 2022-05-02  Spring2022       ¥ 399.00
# 12           CO            COL      COP 2022-05-02  Spring2022    249,000 COP
# 13           CR            CRI      CRC 2022-05-02  Spring2022     39,990 CRC
# 14           CY            CYP      EUR 2022-05-02  Spring2022      49.95 EUR
# 15           CZ            CZE      CZK 2022-05-02  Spring2022       1,199 Kč
# 16           DE            DEU      EUR 2022-05-02  Spring2022      49.95 EUR
# 17           DK            DNK      DKK 2022-05-02  Spring2022     459.00 DKK
# 18           DO            DOM      DOP 2022-05-02  Spring2022      3,995 DOP
# 19           DZ            DZA      DZD 2022-05-02  Spring2022      9,900 DZD
# 20           EE            EST      EUR 2022-05-02  Spring2022      49.95 EUR
# 21           EG            EGY      EGP 2022-05-02  Spring2022      1,199 EGP
# 22           ES            ESP      EUR 2022-05-02  Spring2022      39.95 EUR
# 23           FI            FIN      EUR 2022-05-02  Spring2022      49.95 EUR
# 24           FR            FRA      EUR 2022-05-02  Spring2022      49.95 EUR
# 25           GE            GEO      GEL 2022-05-02  Spring2022        169 GEL
# 26           GR            GRC      EUR 2022-05-02  Spring2022      39.95 EUR
# 27           GT            GTM      GTQ 2022-05-02  Spring2022     499.00 GTQ
# 28           HK            HKG      HKD 2022-05-02  Spring2022     HKD 499.00
# 29           HN            HND      HNL 2022-05-02  Spring2022   1,495.00 HNL
# 30           HR            HRV      HRK 2022-05-02  Spring2022      299.90 Kn
# 31           HU            HUN      HUF 2022-05-02  Spring2022      15,995 Ft
# 32           ID            IDN      IDR 2022-05-02  Spring2022  1,099,900 IDR
# 33           IE            IRL      EUR 2022-05-02  Spring2022      49.95 EUR
# 34           IL            ISR      ILS 2022-05-02  Spring2022       ₪ 269.00
# 35           IN            IND      INR 2022-05-02  Spring2022     ₹ 4,990.00
# 36           IS            ISL      ISK 2022-05-02  Spring2022      8,495 ISK
# 37           IT            ITA      EUR 2022-05-02  Spring2022      49.95 EUR
# 38           JO            JOR      JOD 2022-05-02  Spring2022      49.00 JOD
# 39           JP            JPN      JPY 2022-05-02  Spring2022      7,590 JPY
# 40           KR            KOR      KRW 2022-05-02  Spring2022       89,000 원
# 41           KW            KWT      KWD 2022-05-02  Spring2022      25.90 KWD
# 42           KZ            KAZ      KZT 2022-05-02  Spring2022  27,990.00 KZT
# 43           LB            LBN      LBP 2022-05-02  Spring2022  1,599,000 LBP
# 44           LT            LTU      EUR 2022-05-02  Spring2022      49.95 EUR
# 45           LU            LUX      EUR 2022-05-02  Spring2022      49.95 EUR
# 46           LV            LVA      EUR 2022-05-02  Spring2022      49.95 EUR
# 47           MA            MAR      MAD 2022-05-02  Spring2022     699.00 MAD
# 48           MC            MCO      EUR 2022-05-02  Spring2022      49.95 EUR
# 49           ME            MNE      EUR 2022-05-02  Spring2022      39.95 EUR
# 50           MK            MKD      MKD 2022-05-02  Spring2022   2,690.00 MKD
# 51           MO            MAC      MOP 2022-05-02  Spring2022     MOP 599.00
# 52           MT            MLT      EUR 2022-05-02  Spring2022      49.95 EUR
# 53           MX            MEX      MXN 2022-05-02  Spring2022   1,299.00 MXN
# 54           MY            MYS      MYR 2022-05-02  Spring2022      259.00 RM
# 55           NL            NLD      EUR 2022-05-02  Spring2022      49.95 EUR
# 56           NO            NOR      NOK 2022-05-02  Spring2022     599.00 NOK
# 57           OM            OMN      OMR 2022-05-02  Spring2022      29.90 OMR
# 58           PA            PAN      PAB 2022-05-02  Spring2022      59.95 PAB
# 59           PH            PHL      PHP 2022-05-02  Spring2022   3,295.00 PHP
# 60           PL            POL      PLN 2022-05-02  Spring2022     199.00 PLN
# 61           PT            PRT      EUR 2022-05-02  Spring2022      39.95 EUR
# 62           QA            QAT      QAR 2022-05-02  Spring2022     299.00 QAR
# 63           RO            ROU      RON 2022-05-02  Spring2022     199.90 lei
# 64           RS            SRB      RSD 2022-05-02  Spring2022      4,990 RSD
# 65           RU            RUS      RUB 2022-05-02  Spring2022     4,999 руб.
# 66           SA            SAU      SAR 2022-05-02  Spring2022     329.00 SAR
# 67           SE            SWE      SEK 2022-05-02  Spring2022     559.00 SEK
# 68           SG            SGP      SGD 2022-05-02  Spring2022       S$ 99.90
# 69           SI            SVN      EUR 2022-05-02  Spring2022      39.95 EUR
# 70           SK            SVK      EUR 2022-05-02  Spring2022      39.95 EUR
# 71           SV            SLV      USD 2022-05-02  Spring2022      65.95 USD
# 72           TH            THA      THB 2022-05-02  Spring2022      2,490 THB
# 73           TN            TUN      TND 2022-05-02  Spring2022     199.00 TND
# 74           TR            TUR      TRY 2022-05-02  Spring2022      659.95 TL
# 75           TW            TWN      TWD 2022-05-02  Spring2022      NT$ 1,990
# 76           UA            UKR      UAH 2022-05-02  Spring2022   1,899.00 UAH
# 77           GB            GBR      GBP 2022-05-02  Spring2022      49.99 GBP
# 78           US            USA      USD 2022-05-02  Spring2022      69.90 USD
#
#     itemprice          rate    price_USD
# 0          35      0.951506    36.783793
# 1         299      3.673100    81.402630
# 2        4990    114.659201    43.520275
# 3       32900    453.488078    72.548765
# 4         119      1.700000    70.000000
# 5          85      1.858818    45.727984
# 6          49      0.951506    51.497311
# 7          89      1.860988    47.824059
# 8          29      0.376990    76.925117
# 9          79      1.287150    61.375908
# 10         69      0.977657    70.576900
# 11        399      6.608500    60.376787
# 12     249000   3963.950053    62.816130
# 13      39990    661.990872    60.408688
# 14         49      0.951506    51.497311
# 15       1199     23.499800    51.021711
# 16         49      0.951506    51.497311
# 17        459      7.078502    64.844228
# 18       3995     55.139832    72.452161
# 19       9900    144.743339    68.396930
# 20         49      0.951506    51.497311
# 21       1199     18.477713    64.888983
# 22         39      0.951506    40.987655
# 23         49      0.951506    51.497311
# 24         49      0.951506    51.497311
# 25        169      3.040000    55.592105
# 26         39      0.951506    40.987655
# 27        499      7.670763    65.052199
# 28        499      7.847955    63.583443
# 29       1495     24.511089    60.992802
# 30        299      7.194400    41.560102
# 31      15995    363.363771    44.019248
# 32    1099900  14526.600000    75.716272
# 33         49      0.951506    51.497311
# 34        269      3.356805    80.135724
# 35       4990     76.525450    65.207065
# 36       8495    130.380000    65.155699
# 37         49      0.951506    51.497311
# 38         49      0.709000    69.111425
# 39       7590    130.105750    58.337160
# 40      89000   1267.361827    70.224618
# 41         25      0.306637    81.529626
# 42      27990    443.560722    63.102972
# 43    1599000   1515.249084  1055.272045
# 44         49      0.951506    51.497311
# 45         49      0.951506    51.497311
# 46         49      0.951506    51.497311
# 47        699     10.011500    69.819707
# 48         49      0.951506    51.497311
# 49         39      0.951506    40.987655
# 50       2690     58.638794    45.874068
# 51        599      8.086166    74.077134
# 52         49      0.951506    51.497311
# 53       1299     20.461808    63.484126
# 54        259      4.353500    59.492362
# 55         49      0.951506    51.497311
# 56        599      9.440872    63.447529
# 57         29      0.384985    75.327610
# 58         59      1.000000    59.000000
# 59       3295     52.545001    62.708154
# 60        199      4.466278    44.556116
# 61         39      0.951506    40.987655
# 62        299      3.641000    82.120297
# 63        199      4.707500    42.272969
# 64       4990    111.584743    44.719375
# 65       4999     70.700000    70.707214
# 66        329      3.750880    87.712750
# 67        559      9.911338    56.400054
# 68         99      1.385695    71.444293
# 69         39      0.951506    40.987655
# 70         39      0.951506    40.987655
# 71         65      1.000000    65.000000
# 72       2490     34.470863    72.234919
# 73        199      3.064000    64.947781
# 74        659     14.890400    44.256702
# 75       1990     29.501200    67.454883
# 76       1899     29.412465    64.564463
# 77         49      0.800057    61.245636
# 78         69      1.000000    69.000000

# %%
df.to_csv('C:/Users/Carolina Mendoza/Documents/Applied Analytics/Proyectos/zara.csv')

# %%
#!pip install streamlit

# %%
geojson_url = 'https://raw.githubusercontent.com/python-visualization/folium/master/examples/data/world-countries.json'
response = requests.get(geojson_url)
geojson = response.json()

geojson['features'][0]
# Out:
# {'type': 'Feature',
#  'properties': {'name': 'Afghanistan'},
#  'geometry': {'type': 'Polygon',
#   'coordinates': [[[61.210817, 35.650072],
#     [62.230651, 35.270664],
#     [62.984662, 35.404041],
#     [63.193538, 35.857166],
#     [63.982896, 36.007957],
#     [64.546479, 36.312073],
#     [64.746105, 37.111818],
#     [65.588948, 37.305217],
#     [65.745631, 37.661164],
#     [66.217385, 37.39379],
#     [66.518607, 37.362784],
#     [67.075782, 37.356144],
#     [67.83, 37.144994],
#     [68.135562, 37.023115],
#     [68.859446, 37.344336],
#     [69.196273, 37.151144],
#     [69.518785, 37.608997],
#     [70.116578, 37.588223],
#     [70.270574, 37.735165],
#     [70.376304, 38.138396],
#     [70.806821, 38.486282],
#     [71.348131, 38.258905],
#     [71.239404, 37.953265],
#     [71.541918, 37.905774],
#     [71.448693, 37.065645],
#     [71.844638, 36.738171],
#     [72.193041, 36.948288],
#     [72.63689, 37.047558],
#     [73.260056, 37.495257],
#     [73.948696, 37.421566],
#     [74.980002, 37.41999],
#     [75.158028, 37.133031],
#     [74.575893, 37.020841],
#     [74.067552, 36.836176],
#     [72.920025, 36.720007],
#     [71.846292, 36.509942],
#     [71.262348, 36.074388],
#     [71.498768, 35.650563],
#     [71.613076, 35.153203],
#     [71.115019, 34.733126],
#     [71.156773, 34.348911],
#     [70.881803, 33.988856],
#     [69.930543, 34.02012],
#     [70.323594, 33.358533],
#     [69.687147, 33.105499],
#     [69.262522, 32.501944],
#     [69.317764, 31.901412],
#     [68.926677, 31.620189],
#     [68.556932, 31.71331],
#     [67.792689, 31.58293],
#     [67.683394, 31.303154],
#     [66.938891, 31.304911],
#     [66.381458, 30.738899],
#     [66.346473, 29.887943],
#     [65.046862, 29.472181],
#     [64.350419, 29.560031],
#     [64.148002, 29.340819],
#     [63.550261, 29.468331],
#     [62.549857, 29.318572],
#     [60.874248, 29.829239],
#     [61.781222, 30.73585],
#     [61.699314, 31.379506],
#     [60.941945, 31.548075],
#     [60.863655, 32.18292],
#     [60.536078, 32.981269],
#     [60.9637, 33.528832],
#     [60.52843, 33.676446],
#     [60.803193, 34.404102],
#     [61.210817, 35.650072]]]},
#  'id': 'AFG'}

# %%
map_data = df[['country_code_3', 'price_USD']]
map_data.head()
# Out:
#   country_code_3  price_USD
# 0            AND  36.783793
# 1            ARE  81.402630
# 2            ALB  43.520275
# 3            ARM  72.548765
# 4            AZE  70.000000

# %%
# !pip install folium
# Out:
# Requirement already satisfied: folium in c:\users\carolina mendoza\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (0.12.1.post1)
# Requirement already satisfied: requests in c:\users\carolina mendoza\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from folium) (2.27.1)
# Requirement already satisfied: jinja2>=2.9 in c:\users\carolina mendoza\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from folium) (3.0.3)
# Requirement already satisfied: numpy in c:\users\carolina mendoza\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from folium) (1.21.2)
# Requirement already satisfied: branca>=0.3.0 in c:\users\carolina mendoza\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from folium) (0.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\carolina mendoza\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from jinja2>=2.9->folium) (2.0.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\carolina mendoza\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from requests->folium) (2.0.11)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\carolina mendoza\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from requests->folium) (1.26.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\carolina mendoza\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from requests->folium) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\carolina mendoza\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from requests->folium) (3.3)
# WARNING: You are using pip version 22.0.3; however, version 22.1 is available.
# You should consider upgrading via the 'C:\Users\Carolina Mendoza\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.

# %%
import folium
M = folium.Map(location=[20, 10], zoom_start=2)

folium.Choropleth(
    geo_data=geojson,
    data=map_data,
    columns=['country_code_3', 'price_USD'],
    key_on='feature.id',
    fill_color='YlGnBu',
    fill_opacity=0.7,
    line_opacity=0.2,
    popup=['country_code_3'],
    tooltip=['country_code_3','price_USD'],
).add_to(M)

M
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6e52db7ec322d1ddf74a109370f39b56 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6e52db7ec322d1ddf74a109370f39b56&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_6e52db7ec322d1ddf74a109370f39b56 = L.map(
#                 &quot;map_6e52db7ec322d1ddf74a109370f39b56&quot;,
#                 {
#                     center: [20.0, 10.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_94a23d5d7f91f76fafa7b90a48c2ae5e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6e52db7ec322d1ddf74a109370f39b56);
#
#
#             var choropleth_36d2fa188a54b53e92143786c0711cb5 = L.featureGroup(
#                 {}
#             ).addTo(map_6e52db7ec322d1ddf74a109370f39b56);
#
#
#         function geo_json_cd5e78c116fcc5e2ef950855e8e89a46_styler(feature) {
#             switch(feature.properties.name) {
#                 case &quot;Albania&quot;: case &quot;United Arab Emirates&quot;: case &quot;Armenia&quot;: case &quot;Azerbaijan&quot;: case &quot;Belgium&quot;: case &quot;Bulgaria&quot;: case &quot;Bosnia and Herzegovina&quot;: case &quot;Canada&quot;: case &quot;Switzerland&quot;: case &quot;China&quot;: case &quot;Colombia&quot;: case &quot;Costa Rica&quot;: case &quot;Cyprus&quot;: case &quot;Czech Republic&quot;: case &quot;Germany&quot;: case &quot;Denmark&quot;: case &quot;Dominican Republic&quot;: case &quot;Algeria&quot;: case &quot;Egypt&quot;: case &quot;Spain&quot;: case &quot;Estonia&quot;: case &quot;Finland&quot;: case &quot;France&quot;: case &quot;United Kingdom&quot;: case &quot;Georgia&quot;: case &quot;Greece&quot;: case &quot;Guatemala&quot;: case &quot;Honduras&quot;: case &quot;Croatia&quot;: case &quot;Hungary&quot;: case &quot;Indonesia&quot;: case &quot;India&quot;: case &quot;Ireland&quot;: case &quot;Iceland&quot;: case &quot;Israel&quot;: case &quot;Italy&quot;: case &quot;Jordan&quot;: case &quot;Japan&quot;: case &quot;Kazakhstan&quot;: case &quot;South Korea&quot;: case &quot;Kuwait&quot;: case &quot;Lithuania&quot;: case &quot;Luxembourg&quot;: case &quot;Latvia&quot;: case &quot;Morocco&quot;: case &quot;Mexico&quot;: case &quot;Macedonia&quot;: case &quot;Montenegro&quot;: case &quot;Malaysia&quot;: case &quot;Netherlands&quot;: case &quot;Norway&quot;: case &quot;Oman&quot;: case &quot;Panama&quot;: case &quot;Philippines&quot;: case &quot;Poland&quot;: case &quot;Portugal&quot;: case &quot;Qatar&quot;: case &quot;Romania&quot;: case &quot;Russia&quot;: case &quot;Saudi Arabia&quot;: case &quot;El Salvador&quot;: case &quot;Republic of Serbia&quot;: case &quot;Slovakia&quot;: case &quot;Slovenia&quot;: case &quot;Sweden&quot;: case &quot;Thailand&quot;: case &quot;Tunisia&quot;: case &quot;Turkey&quot;: case &quot;Taiwan&quot;: case &quot;Ukraine&quot;: case &quot;United States of America&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffcc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;Lebanon&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#253494&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_cd5e78c116fcc5e2ef950855e8e89a46_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_cd5e78c116fcc5e2ef950855e8e89a46 = L.geoJson(null, {
#                 onEachFeature: geo_json_cd5e78c116fcc5e2ef950855e8e89a46_onEachFeature,
#
#                 style: geo_json_cd5e78c116fcc5e2ef950855e8e89a46_styler,
#         });
#
#         function geo_json_cd5e78c116fcc5e2ef950855e8e89a46_add (data) {
#             geo_json_cd5e78c116fcc5e2ef950855e8e89a46
#                 .addData(data)
#                 .addTo(choropleth_36d2fa188a54b53e92143786c0711cb5);
#         }
#             geo_json_cd5e78c116fcc5e2ef950855e8e89a46_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[61.210817, 35.650072], [62.230651, 35.270664], [62.984662, 35.404041], [63.193538, 35.857166], [63.982896, 36.007957], [64.546479, 36.312073], [64.746105, 37.111818], [65.588948, 37.305217], [65.745631, 37.661164], [66.217385, 37.39379], [66.518607, 37.362784], [67.075782, 37.356144], [67.83, 37.144994], [68.135562, 37.023115], [68.859446, 37.344336], [69.196273, 37.151144], [69.518785, 37.608997], [70.116578, 37.588223], [70.27

# %%
# !pip install branca
# Out:
# Requirement already satisfied: branca in c:\users\carolina mendoza\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (0.5.0)
# Requirement already satisfied: jinja2 in c:\users\carolina mendoza\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from branca) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\carolina mendoza\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from jinja2->branca) (2.0.1)
# WARNING: You are using pip version 22.0.3; however, version 22.1 is available.
# You should consider upgrading via the 'C:\Users\Carolina Mendoza\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.

# %%
import branca.colormap as cmp

# %%
step = cmp.StepColormap(
 ['yellow', 'green', 'purple'],
 vmin=3, vmax=10,
 index=[3, 6, 8, 10],  #for change in the colors, not used fr linear
 caption='Color Scale for Map'    #Caption for Color scale or Legend
)
step
# Out:
# <svg height="50" width="500"><line x1="0" y1="0" x2="0" y2="20" style="stroke:#ffff00ff;stroke-width:3;" /><line x1="1" y1="0" x2="1" y2="20" style="stroke:#ffff00ff;stroke-width:3;" /><line x1="2" y1="0" x2="2" y2="20" style="stroke:#ffff00ff;stroke-width:3;" /><line x1="3" y1="0" x2="3" y2="20" style="stroke:#ffff00ff;stroke-width:3;" /><line x1="4" y1="0" x2="4" y2="20" style="stroke:#ffff00ff;stroke-width:3;" /><line x1="5" y1="0" x2="5" y2="20" style="stroke:#ffff00ff;stroke-width:3;" /><line x1="6" y1="0" x2="6" y2="20" style="stroke:#ffff00ff;stroke-width:3;" /><line x1="7" y1="0" x2="7" y2="20" style="stroke:#ffff00ff;stroke-width:3;" /><line x1="8" y1="0" x2="8" y2="20" style="stroke:#ffff00ff;stroke-width:3;" /><line x1="9" y1="0" x2="9" y2="20" style="stroke:#ffff00ff;stroke-width:3;" /><line x1="10" y1="0" x2="10" y2="20" style="stroke:#ffff00ff;stroke-width:3;" /><line x1="11" y1="0" x2="11" y2="20" style="stroke:#ffff00ff;stroke-width:3;" /><line x1="12" y1="0" x2="12" y2="20" style="stroke:#ffff00ff;stroke-width:3;" /><line x1="13" y1="0" x2="13" y2="20" style="stroke:#ffff00ff;stroke-width:3;" /><line x1="14" y1="0" x2="14" y2="20" style="stroke:#ffff00ff;stroke-width:3;" /><line x1="15" y1="0" x2="15" y2="20" style="stroke:#ffff00ff;stroke-width:3;" /><line x1="16" y1="0" x2="16" y2="20" style="stroke:#ffff00ff;stroke-width:3;" /><line x1="17" y1="0" x2="17" y2="20" style="stroke:#ffff00ff;stroke-width:3;" /><line x1="18" y1="0" x2="18" y2="20" style="stroke:#ffff00ff;stroke-width:3;" /><line x1="19" y1="0" x2="19" y2="20" style="stroke:#ffff00ff;stroke-width:3;" /><line x1="20" y1="0" x2="20" y2="20" style="stroke:#ffff00ff;stroke-width:3;" /><line x1="21" y1="0" x2="21" y2="20" style="stroke:#ffff00ff;stroke-width:3;" /><line x1="22" y1="0" x2="22" y2="20" style="stroke:#ffff00ff;stroke-width:3;" /><line x1="23" y1="0" x2="23" y2="20" style="stroke:#ffff00ff;stroke-width:3;" /><line x1="24" y1="0" x2="24" y2="20" style="stroke:#ffff00ff;stroke-width:3;" /><line x1="25" y1="0" x2="25" y2="20" style="stroke:#ffff00ff;stroke-width:3;" /><line x1="26" y1="0" x2="26" y2="20" style="stroke:#ffff00ff;stroke-width:3;" /><line x1="27" y1="0" x2="27" y2="20" style="stroke:#ffff00ff;stroke-width:3;" /><line x1="28" y1="0" x2="28" y2="20" style="stroke:#ffff00ff;stroke-width:3;" /><line x1="29" y1="0" x2="29" y2="20" style="stroke:#ffff00ff;stroke-width:3;" /><line x1="30" y1="0" x2="30" y2="20" style="stroke:#ffff00ff;stroke-width:3;" /><line x1="31" y1="0" x2="31" y2="20" style="stroke:#ffff00ff;stroke-width:3;" /><line x1="32" y1="0" x2="32" y2="20" style="stroke:#ffff00ff;stroke-width:3;" /><line x1="33" y1="0" x2="33" y2="20" style="stroke:#ffff00ff;stroke-width:3;" /><line x1="34" y1="0" x2="34" y2="20" style="stroke:#ffff00ff;stroke-width:3;" /><line x1="35" y1="0" x2="35" y2="20" style="stroke:#ffff00ff;stroke-width:3;" /><line x1="36" y1="0" x2="36" y2="20" style="stroke:#ffff00ff;stroke-width:3;" /><line x1="37" y1="0" x2="37" y2="20" style="stroke:#ffff00ff;stroke-width:3;" /><line x1="38" y1="0" x2="38" y2="20" style="stroke:#ffff00ff;stroke-width:3;" /><line x1="39" y1="0" x2="39" y2="20" style="stroke:#ffff00ff;stroke-width:3;" /><line x1="40" y1="0" x2="40" y2="20" style="stroke:#ffff00ff;stroke-width:3;" /><line x1="41" y1="0" x2="41" y2="20" style="stroke:#ffff00ff;stroke-width:3;" /><line x1="42" y1="0" x2="42" y2="20" style="stroke:#ffff00ff;stroke-width:3;" /><line x1="43" y1="0" x2="43" y2="20" style="stroke:#ffff00ff;stroke-width:3;" /><line x1="44" y1="0" x2="44" y2="20" style="stroke:#ffff00ff;stroke-width:3;" /><line x1="45" y1="0" x2="45" y2="20" style="stroke:#ffff00ff;stroke-width:3;" /><line x1="46" y1="0" x2="46" y2="20" style="stroke:#ffff00ff;stroke-width:3;" /><line x1="47" y1="0" x2="47" y2="20" style="stroke:#ffff00ff;stroke-width:3;" /><line x1="48" y1="0" x2="48" y2="20" style="stroke:#ffff00ff;stroke-width:3;" /><line x1="49" y1="0" x2="49" y2="20" style="stroke:#ffff00ff;stroke-wid ...

# %%
#Adding MongoDB server details 
from pymongo import MongoClient 
client = MongoClient("mongodb+srv://admin:admin@cluster0.hl9j5.mongodb.net/test?retryWrites=true&w=majority") ## or MongoClient("localhost:27")

#Create Database
db = client.zaraindex

# %%
#Collection variable
collection=db.zara

# %%
dataframe=pd.DataFrame(df)
print (type(dataframe).__name__)
print(dataframe)
# Out:
# DataFrame
#                          name          price               country_name  \
# 0   PRINTED LINEN BLEND DRESS      35.00 EUR                    Andorra
# 1   PRINTED LINEN BLEND DRESS     299.00 AED       United Arab Emirates
# 2   PRINTED LINEN BLEND DRESS      4,990 ALL                    Albania
# 3   PRINTED LINEN BLEND DRESS  32,900.00 AMD                    Armenia
# 4   PRINTED LINEN BLEND DRESS     119.00 AZN                 Azerbaijan
# 5   PRINTED LINEN BLEND DRESS      85.95 BAM     Bosnia and Herzegovina
# 6   PRINTED LINEN BLEND DRESS      49.95 EUR                    Belgium
# 7   PRINTED LINEN BLEND DRESS       89.95 лв                   Bulgaria
# 8   PRINTED LINEN BLEND DRESS      29.90 BHD                    Bahrain
# 9     LINEN BLEND PRINT DRESS      79.90 CAD                     Canada
# 10  PRINTED LINEN BLEND DRESS      69.90 CHF                Switzerland
# 11  PRINTED LINEN BLEND DRESS       ¥ 399.00                      China
# 12    LINEN BLEND PRINT DRESS    249,000 COP                   Colombia
# 13    LINEN BLEND PRINT DRESS     39,990 CRC                 Costa Rica
# 14  PRINTED LINEN BLEND DRESS      49.95 EUR                     Cyprus
# 15  PRINTED LINEN BLEND DRESS       1,199 Kč                    Czechia
# 16  PRINTED LINEN BLEND DRESS      49.95 EUR                    Germany
# 17  PRINTED LINEN BLEND DRESS     459.00 DKK                    Denmark
# 18    LINEN BLEND PRINT DRESS      3,995 DOP         Dominican Republic
# 19  PRINTED LINEN BLEND DRESS      9,900 DZD                    Algeria
# 20  PRINTED LINEN BLEND DRESS      49.95 EUR                    Estonia
# 21  PRINTED LINEN BLEND DRESS      1,199 EGP                      Egypt
# 22  PRINTED LINEN BLEND DRESS      39.95 EUR                      Spain
# 23  PRINTED LINEN BLEND DRESS      49.95 EUR                    Finland
# 24  PRINTED LINEN BLEND DRESS      49.95 EUR                     France
# 25  PRINTED LINEN BLEND DRESS        169 GEL                    Georgia
# 26  PRINTED LINEN BLEND DRESS      39.95 EUR                     Greece
# 27    LINEN BLEND PRINT DRESS     499.00 GTQ                  Guatemala
# 28  PRINTED LINEN BLEND DRESS     HKD 499.00                  Hong Kong
# 29    LINEN BLEND PRINT DRESS   1,495.00 HNL                   Honduras
# 30  PRINTED LINEN BLEND DRESS      299.90 Kn                    Croatia
# 31  PRINTED LINEN BLEND DRESS      15,995 Ft                    Hungary
# 32  PRINTED LINEN BLEND DRESS  1,099,900 IDR                  Indonesia
# 33  PRINTED LINEN BLEND DRESS      49.95 EUR                    Ireland
# 34  PRINTED LINEN BLEND DRESS       ₪ 269.00                     Israel
# 35  PRINTED LINEN BLEND DRESS     ₹ 4,990.00                      India
# 36  PRINTED LINEN BLEND DRESS      8,495 ISK                    Iceland
# 37  PRINTED LINEN BLEND DRESS      49.95 EUR                      Italy
# 38  PRINTED LINEN BLEND DRESS      49.00 JOD                     Jordan
# 39  PRINTED LINEN BLEND DRESS      7,590 JPY                      Japan
# 40  PRINTED LINEN BLEND DRESS       89,000 원         Korea, Republic of
# 41  PRINTED LINEN BLEND DRESS      25.90 KWD                     Kuwait
# 42  PRINTED LINEN BLEND DRESS  27,990.00 KZT                 Kazakhstan
# 43  PRINTED LINEN BLEND DRESS  1,599,000 LBP                    Lebanon
# 44  PRINTED LINEN BLEND DRESS      49.95 EUR                  Lithuania
# 45  PRINTED LINEN BLEND DRESS      49.95 EUR                 Luxembourg
# 46  PRINTED LINEN BLEND DRESS      49.95 EUR                     Latvia
# 47  PRINTED LINEN BLEND DRESS     699.00 MAD                    Morocco
# 48  PRINTED LINEN BLEND DRESS      49.95 EUR                     Monaco
# 49  PRINTED LINEN BLEND DRESS      39.95 EUR                 Montenegro
# 50  PRINTED LINEN BLEND DRESS   2,690.00 MKD            North Macedonia
# 51  PRINTED LINEN BLEND DRESS     MOP 599.00                      Macao
# 52  PRINTED LINEN BLEND DRESS      49.95 EUR                      Malta
# 53    LINEN BLEND PRINT DRESS   1,299.00 MXN                     Mexico
# 54  PRINTED LINEN BLEND DRESS      259.00 RM                   Malaysia
# 55  PRINTED LINEN BLEND DRESS      49.95 EUR                Netherlands
# 56  PRINTED LINEN BLEND DRESS     599.00 NOK                     Norway
# 57  PRINTED LINEN BLEND DRESS      29.90 OMR                       Oman
# 58    LINEN BLEND PRINT DRESS      59.95 PAB                     Panama
# 59  PRINTED LINEN BLEND DRESS   3,295.00 PHP                Philippines
# 60  PRINTED LINEN BLEND DRESS     199.00 PLN                     Poland
# 61  PRINTED LINEN BLEND DRESS      39.95 EUR                   Portugal
# 62  PRINTED LINEN BLEND DRESS     299.00 QAR                      Qatar
# 63  PRINTED LINEN BLEND DRESS     199.90 lei                    Romania
# 64  PRINTED LINEN BLEND DRESS      4,990 RSD                     Serbia
# 65  PRINTED LINEN BLEND DRESS     4,999 руб.         Russian Federation
# 66  PRINTED LINEN BLEND DRESS     329.00 SAR               Saudi Arabia
# 67  PRINTED LINEN BLEND DRESS     559.00 SEK                     Sweden
# 68  PRINTED LINEN BLEND DRESS       S$ 99.90                  Singapore
# 69  PRINTED LINEN BLEND DRESS      39.95 EUR                   Slovenia
# 70  PRINTED LINEN BLEND DRESS      39.95 EUR                   Slovakia
# 71    LINEN BLEND PRINT DRESS      65.95 USD                El Salvador
# 72  PRINTED LINEN BLEND DRESS      2,490 THB                   Thailand
# 73  PRINTED LINEN BLEND DRESS     199.00 TND                    Tunisia
# 74  PRINTED LINEN BLEND DRESS      659.95 TL                     Turkey
# 75  PRINTED LINEN BLEND DRESS      NT$ 1,990  Taiwan, Province of China
# 76  PRINTED LINEN BLEND DRESS   1,899.00 UAH                    Ukraine
# 77  PRINTED LINEN BLEND DRESS      49.99 GBP             United Kingdom
# 78    LINEN BLEND PRINT DRESS      69.90 USD              United States
#
#    country_code country_code_3 currency       date   coleccion      realprice  \
# 0            AD            AND      EUR 2022-05-02  Spring2022      35.00 EUR
# 1            AE            ARE      AED 2022-05-02  Spring2022     299.00 AED
# 2            AL            ALB      ALL 2022-05-02  Spring2022      4,990 ALL
# 3            AM            ARM      AMD 2022-05-02  Spring2022  32,900.00 AMD
# 4            AZ            AZE      AZN 2022-05-02  Spring2022     119.00 AZN
# 5            BA            BIH      BAM 2022-05-02  Spring2022      85.95 BAM
# 6            BE            BEL      EUR 2022-05-02  Spring2022      49.95 EUR
# 7            BG            BGR      BGN 2022-05-02  Spring2022       89.95 лв
# 8            BH            BHR      BHD 2022-05-02  Spring2022      29.90 BHD
# 9            CA            CAN      CAD 2022-05-02  Spring2022      79.90 CAD
# 10           CH            CHE      CHF 2022-05-02  Spring2022      69.90 CHF
# 11           CN            CHN      CNY 2022-05-02  Spring2022       ¥ 399.00
# 12           CO            COL      COP 2022-05-02  Spring2022    249,000 COP
# 13           CR            CRI      CRC 2022-05-02  Spring2022     39,990 CRC
# 14           CY            CYP      EUR 2022-05-02  Spring2022      49.95 EUR
# 15           CZ            CZE      CZK 2022-05-02  Spring2022       1,199 Kč
# 16           DE            DEU      EUR 2022-05-02  Spring2022      49.95 EUR
# 17           DK            DNK      DKK 2022-05-02  Spring2022     459.00 DKK
# 18           DO            DOM      DOP 2022-05-02  Spring2022      3,995 DOP
# 19           DZ            DZA      DZD 2022-05-02  Spring2022      9,900 DZD
# 20           EE            EST      EUR 2022-05-02  Spring2022      49.95 EUR
# 21           EG            EGY      EGP 2022-05-02  Spring2022      1,199 EGP
# 22           ES            ESP      EUR 2022-05-02  Spring2022      39.95 EUR
# 23           FI            FIN      EUR 2022-05-02  Spring2022      49.95 EUR
# 24           FR            FRA      EUR 2022-05-02  Spring2022      49.95 EUR
# 25           GE            GEO      GEL 2022-05-02  Spring2022        169 GEL
# 26           GR            GRC      EUR 2022-05-02  Spring2022      39.95 EUR
# 27           GT            GTM      GTQ 2022-05-02  Spring2022     499.00 GTQ
# 28           HK            HKG      HKD 2022-05-02  Spring2022     HKD 499.00
# 29           HN            HND      HNL 2022-05-02  Spring2022   1,495.00 HNL
# 30           HR            HRV      HRK 2022-05-02  Spring2022      299.90 Kn
# 31           HU            HUN      HUF 2022-05-02  Spring2022      15,995 Ft
# 32           ID            IDN      IDR 2022-05-02  Spring2022  1,099,900 IDR
# 33           IE            IRL      EUR 2022-05-02  Spring2022      49.95 EUR
# 34           IL            ISR      ILS 2022-05-02  Spring2022       ₪ 269.00
# 35           IN            IND      INR 2022-05-02  Spring2022     ₹ 4,990.00
# 36           IS            ISL      ISK 2022-05-02  Spring2022      8,495 ISK
# 37           IT            ITA      EUR 2022-05-02  Spring2022      49.95 EUR
# 38           JO            JOR      JOD 2022-05-02  Spring2022      49.00 JOD
# 39           JP            JPN      JPY 2022-05-02  Spring2022      7,590 JPY
# 40           KR            KOR      KRW 2022-05-02  Spring2022       89,000 원
# 41           KW            KWT      KWD 2022-05-02  Spring2022      25.90 KWD
# 42           KZ            KAZ      KZT 2022-05-02  Spring2022  27,990.00 KZT
# 43           LB            LBN      LBP 2022-05-02  Spring2022  1,599,000 LBP
# 44           LT            LTU      EUR 2022-05-02  Spring2022      49.95 EUR
# 45           LU            LUX      EUR 2022-05-02  Spring2022      49.95 EUR
# 46           LV            LVA      EUR 2022-05-02  Spring2022      49.95 EUR
# 47           MA            MAR      MAD 2022-05-02  Spring2022     699.00 MAD
# 48           MC            MCO      EUR 2022-05-02  Spring2022      49.95 EUR
# 49           ME            MNE      EUR 2022-05-02  Spring2022      39.95 EUR
# 50           MK            MKD      MKD 2022-05-02  Spring2022   2,690.00 MKD
# 51           MO            MAC      MOP 2022-05-02  Spring2022     MOP 599.00
# 52           MT            MLT      EUR 2022-05-02  Spring2022      49.95 EUR
# 53           MX            MEX      MXN 2022-05-02  Spring2022   1,299.00 MXN
# 54           MY            MYS      MYR 2022-05-02  Spring2022      259.00 RM
# 55           NL            NLD      EUR 2022-05-02  Spring2022      49.95 EUR
# 56           NO            NOR      NOK 2022-05-02  Spring2022     599.00 NOK
# 57           OM            OMN      OMR 2022-05-02  Spring2022      29.90 OMR
# 58           PA            PAN      PAB 2022-05-02  Spring2022      59.95 PAB
# 59           PH            PHL      PHP 2022-05-02  Spring2022   3,295.00 PHP
# 60           PL            POL      PLN 2022-05-02  Spring2022     199.00 PLN
# 61           PT            PRT      EUR 2022-05-02  Spring2022      39.95 EUR
# 62           QA            QAT      QAR 2022-05-02  Spring2022     299.00 QAR
# 63           RO            ROU      RON 2022-05-02  Spring2022     199.90 lei
# 64           RS            SRB      RSD 2022-05-02  Spring2022      4,990 RSD
# 65           RU            RUS      RUB 2022-05-02  Spring2022     4,999 руб.
# 66           SA            SAU      SAR 2022-05-02  Spring2022     329.00 SAR
# 67           SE            SWE      SEK 2022-05-02  Spring2022     559.00 SEK
# 68           SG            SGP      SGD 2022-05-02  Spring2022       S$ 99.90
# 69           SI            SVN      EUR 2022-05-02  Spring2022      39.95 EUR
# 70           SK            SVK      EUR 2022-05-02  Spring2022      39.95 EUR
# 71           SV            SLV      USD 2022-05-02  Spring2022      65.95 USD
# 72           TH            THA      THB 2022-05-02  Spring2022      2,490 THB
# 73           TN            TUN      TND 2022-05-02  Spring2022     199.00 TND
# 74           TR            TUR      TRY 2022-05-02  Spring2022      659.95 TL
# 75           TW            TWN      TWD 2022-05-02  Spring2022      NT$ 1,990
# 76           UA            UKR      UAH 2022-05-02  Spring2022   1,899.00 UAH
# 77           GB            GBR      GBP 2022-05-02  Spring2022      49.99 GBP
# 78           US            USA      USD 2022-05-02  Spring2022      69.90 USD
#
#     itemprice          rate    price_USD
# 0          35      0.951506    36.783793
# 1         299      3.673100    81.402630
# 2        4990    114.659201    43.520275
# 3       32900    453.488078    72.548765
# 4         119      1.700000    70.000000
# 5          85      1.858818    45.727984
# 6          49      0.951506    51.497311
# 7          89      1.860988    47.824059
# 8          29      0.376990    76.925117
# 9          79      1.287150    61.375908
# 10         69      0.977657    70.576900
# 11        399      6.608500    60.376787
# 12     249000   3963.950053    62.816130
# 13      39990    661.990872    60.408688
# 14         49      0.951506    51.497311
# 15       1199     23.499800    51.021711
# 16         49      0.951506    51.497311
# 17        459      7.078502    64.844228
# 18       3995     55.139832    72.452161
# 19       9900    144.743339    68.396930
# 20         49      0.951506    51.497311
# 21       1199     18.477713    64.888983
# 22         39      0.951506    40.987655
# 23         49      0.951506    51.497311
# 24         49      0.951506    51.497311
# 25        169      3.040000    55.592105
# 26         39      0.951506    40.987655
# 27        499      7.670763    65.052199
# 28        499      7.847955    63.583443
# 29       1495     24.511089    60.992802
# 30        299      7.194400    41.560102
# 31      15995    363.363771    44.019248
# 32    1099900  14526.600000    75.716272
# 33         49      0.951506    51.497311
# 34        269      3.356805    80.135724
# 35       4990     76.525450    65.207065
# 36       8495    130.380000    65.155699
# 37         49      0.951506    51.497311
# 38         49      0.709000    69.111425
# 39       7590    130.105750    58.337160
# 40      89000   1267.361827    70.224618
# 41         25      0.306637    81.529626
# 42      27990    443.560722    63.102972
# 43    1599000   1515.249084  1055.272045
# 44         49      0.951506    51.497311
# 45         49      0.951506    51.497311
# 46         49      0.951506    51.497311
# 47        699     10.011500    69.819707
# 48         49      0.951506    51.497311
# 49         39      0.951506    40.987655
# 50       2690     58.638794    45.874068
# 51        599      8.086166    74.077134
# 52         49      0.951506    51.497311
# 53       1299     20.461808    63.484126
# 54        259      4.353500    59.492362
# 55         49      0.951506    51.497311
# 56        599      9.440872    63.447529
# 57         29      0.384985    75.327610
# 58         59      1.000000    59.000000
# 59       3295     52.545001    62.708154
# 60        199      4.466278    44.556116
# 61         39      0.951506    40.987655
# 62        299      3.641000    82.120297
# 63        199      4.707500    42.272969
# 64       4990    111.584743    44.719375
# 65       4999     70.700000    70.707214
# 66        329      3.750880    87.712750
# 67        559      9.911338    56.400054
# 68         99      1.385695    71.444293
# 69         39      0.951506    40.987655
# 70         39      0.951506    40.987655
# 71         65      1.000000    65.000000
# 72       2490     34.470863    72.234919
# 73        199      3.064000    64.947781
# 74        659     14.890400    44.256702
# 75       1990     29.501200    67.454883
# 76       1899     29.412465    64.564463
# 77         49      0.800057    61.245636
# 78         69      1.000000    69.000000

# %%
df['price_USD'].describe()
# Out:
# count      79.000000
# mean       71.838481
# std       112.717555
# min        36.783793
# 25%        51.497311
# 50%        60.992802
# 75%        69.055712
# max      1055.272045
# Name: price_USD, dtype: float64

# %%
import requests
import pandas as pd
import pymongo

# %%
minprice=df['price_USD'].min()
maxprice=df['price_USD'].max()

# %%
#Pushing Data to collection
post_id = collection.insert_many(dataframe)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [58], in <module>
#       1 #Pushing Data to collection
# ----> 2 post_id = collection.insert_many(dataframe)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pymongo\collection.py:571, in Collection.insert_many(self, documents, ordered, bypass_document_validation, session)
#     530 def insert_many(self, documents, ordered=True,
#     531                 bypass_document_validation=False, session=None):
#     532     """Insert an iterable of documents.
#     533
#     534       >>> db.test.count_documents({})
#    (...)
#     569     .. versionadded:: 3.0
#     570     """
# --> 571     if (not isinstance(documents, abc.Iterable)
#     572             or isinstance(documents, abc.Mapping)
#     573             or not documents):
#     574         raise TypeError("documents must be a non-empty list")
#     575     inserted_ids = []
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\generic.py:1535, in NDFrame.__nonzero__(self)
#    1533 @final
#    1534 def __nonzero__(self):
# -> 1535     raise ValueError(
#    1536         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1537         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1538     )
#
# ValueError: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
collection.count_documents({})

# %%
import branca.colormap as cmp
linear = cmp.LinearColormap(
    ['yellow', 'green', 'purple'],
    vmin=minprice, vmax=maxprice,
    caption='Color Scale for Map' #Caption for Color scale or Legend
)
linear

# %%
df_dict = df.set_index('country_code_3')['price_USD']
#geo_json_data = json.loads(requests.get(state_geo).text)
usa_linear = folium.Map([48,-102], tiles='cartodbpositron', zoom_start=3)
folium.GeoJson(
    geojson,
    style_function=lambda feature: {
        'fillColor': linear(df_dict[feature['country_code']]),
        'color': 'black',     #border color for the color fills
        'weight': 1,          #how thick the border has to be
        'dashArray': '5, 3'  #dashed lines length,space between them
    }
).add_to(usa_linear)
linear.add_to(usa_linear)   #adds colorscale or legend
usa_linear

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\carolina mendoza\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (0.11.2)
# Requirement already satisfied: numpy>=1.15 in c:\users\carolina mendoza\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from seaborn) (1.21.2)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\carolina mendoza\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from seaborn) (3.5.2)
# Requirement already satisfied: scipy>=1.0 in c:\users\carolina mendoza\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from seaborn) (1.8.0)
# Requirement already satisfied: pandas>=0.23 in c:\users\carolina mendoza\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from seaborn) (1.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\carolina mendoza\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib>=2.2->seaborn) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\carolina mendoza\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib>=2.2->seaborn) (3.0.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\carolina mendoza\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\carolina mendoza\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib>=2.2->seaborn) (4.33.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\carolina mendoza\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib>=2.2->seaborn) (9.0.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\carolina mendoza\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\carolina mendoza\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\carolina mendoza\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas>=0.23->seaborn) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\carolina mendoza\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)
# WARNING: You are using pip version 22.0.3; however, version 22.1 is available.
# You should consider upgrading via the 'C:\Users\Carolina Mendoza\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(20,12))

sns.set()
sns.barplot(
    x='price_USD', 
    y='country_name', 
    color='salmon', 
    data=df,
    order=df.sort_values('price_USD', ascending = False).country_name
)

# set labels
plt.xlabel("Price USD", size=10)
plt.ylabel("Country", size=10)
plt.title("All countries", size=18)
plt.tight_layout()

# %%
top10=df.nlargest(10,'price_USD')
bottom10=df.nsmallest(10,'price_USD')

# %%
print(top10)
# Out:
#                          name          price          country_name  \
# 43  PRINTED LINEN BLEND DRESS  1,599,000 LBP               Lebanon
# 66  PRINTED LINEN BLEND DRESS     329.00 SAR          Saudi Arabia
# 62  PRINTED LINEN BLEND DRESS     299.00 QAR                 Qatar
# 41  PRINTED LINEN BLEND DRESS      25.90 KWD                Kuwait
# 1   PRINTED LINEN BLEND DRESS     299.00 AED  United Arab Emirates
# 34  PRINTED LINEN BLEND DRESS       ₪ 269.00                Israel
# 8   PRINTED LINEN BLEND DRESS      29.90 BHD               Bahrain
# 32  PRINTED LINEN BLEND DRESS  1,099,900 IDR             Indonesia
# 57  PRINTED LINEN BLEND DRESS      29.90 OMR                  Oman
# 51  PRINTED LINEN BLEND DRESS     MOP 599.00                 Macao
#
#    country_code country_code_3 currency       date   coleccion      realprice  \
# 43           LB            LBN      LBP 2022-05-02  Spring2022  1,599,000 LBP
# 66           SA            SAU      SAR 2022-05-02  Spring2022     329.00 SAR
# 62           QA            QAT      QAR 2022-05-02  Spring2022     299.00 QAR
# 41           KW            KWT      KWD 2022-05-02  Spring2022      25.90 KWD
# 1            AE            ARE      AED 2022-05-02  Spring2022     299.00 AED
# 34           IL            ISR      ILS 2022-05-02  Spring2022       ₪ 269.00
# 8            BH            BHR      BHD 2022-05-02  Spring2022      29.90 BHD
# 32           ID            IDN      IDR 2022-05-02  Spring2022  1,099,900 IDR
# 57           OM            OMN      OMR 2022-05-02  Spring2022      29.90 OMR
# 51           MO            MAC      MOP 2022-05-02  Spring2022     MOP 599.00
#
#     itemprice          rate    price_USD
# 43    1599000   1515.249084  1055.272045
# 66        329      3.750880    87.712750
# 62        299      3.641000    82.120297
# 41         25      0.306637    81.529626
# 1         299      3.673100    81.402630
# 34        269      3.356805    80.135724
# 8          29      0.376990    76.925117
# 32    1099900  14526.600000    75.716272
# 57         29      0.384985    75.327610
# 51        599      8.086166    74.077134

# %%
plt.figure(figsize=(20,12))

sns.set()
sns.barplot(
    x='price_USD', 
    y='country_name', 
    color='salmon', 
    data=top10,
    order=top10.sort_values('price_USD', ascending = False).country_name
)

# set labels
plt.xlabel("Price USD", size=10)
plt.ylabel("Country", size=10)
plt.title("All countries", size=18)
plt.tight_layout()

# %%
plt.figure(figsize=(20,12))

sns.set()
sns.barplot(
    x='price_USD', 
    y='country_name', 
    color='salmon', 
    data=bottom10,
    order=bottom10.sort_values('price_USD', ascending = False).country_name
)

# set labels
plt.xlabel("Price USD", size=10)
plt.ylabel("Country", size=10)
plt.title("All countries", size=18)
plt.tight_layout()

# %%
# Out:
#   Input In [94]
#     streamlit hello
#               ^
# SyntaxError: invalid syntax
